# %% [markdown]
# # Prática 05: Manejo de Heatmaps en  el Análisis de Datos

# %% [markdown]
# ### Unidad 2: Preparación de los Datos

# %% [markdown]
# **Programa de Estudios:** Ing. en Entornos Virtuales y Negocios Digitales \
# **Asignatura:** Analítica de Datos para Negocios Digitales \
# **Docente:** M.T.I Marco A. Ramírez \
# **Nombre del Estudiante:** María De Los Ángeles García Cortez \
# **Matrícula:** 230538 \
# **Grado/Grupo:** 9° "A" \
# **Periodo:** Mayo - Agosto 2026

# %% [markdown]
# ## Ciencia de datos para el bien social: DonorsChoose
#
# DonorsChoose es una organización sin fines de lucro con sede en Estados Unidos que permite a particulares realizar donaciones directas a proyectos de aulas en escuelas públicas. Para enero de 2018, DonorsChoose.org había financiado un millón de proyectos; de hecho, el 77 % de las escuelas públicas de Estados Unidos ha solicitado al menos un proyecto a través de esta plataforma. DonorsChoose ha compartido un conjunto de datos completo que incluye todos los proyectos anteriores y los recursos asociados, junto con metadatos sobre docentes, escuelas, donantes y donaciones. Esta información permite extraer conocimientos valiosos y desarrollar una solución que posibilite a DonorsChoose.org crear campañas de correo electrónico personalizadas, recomendando solicitudes específicas de aulas a quienes ya han realizado donaciones anteriormente. En este notebook, he llevado a cabo un análisis y una exploración exhaustivos del conjunto de datos compartido. Este documento no solo aporta información clave derivada de los datos de DonorsChoose, sino que también sirve como tutorial para realizar análisis de datos (incluido el análisis exploratorio) y visualizaciones de datos.

# %% [markdown]
# ## Contenido
#
# [1. Preparación del conjunto de datos](#1)
#
# [2. Exploración de los donantes](#2)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.1 Resumen de los donantes](#2.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.2 Donantes de diferentes estados](#2.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.3 Estados con la mayor proporción de donantes respecto a la población](#2.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.4 Visualización de la ubicación de los donantes](#2.4)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.1 Ubicación de los donantes en California](#2.4.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.2 Ubicación de los donantes en Florida](#2.4.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.3 Ubicación de los donantes en Nueva York](#2.4.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.4 Ubicación de los donantes en Texas](#2.4.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.5 Dónde se encuentran los donantes](#2.5)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.6 Donantes docentes y no docentes en diferentes estados](#2.6)
#
# [3. Exploración de las donaciones](#3)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.1 Resumen de las donaciones](#3.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.2 Proyectos y sus donaciones](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.2.1 Proyectos con el mayor número de donantes](#3.2.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.2.2 Proyectos con el mayor monto total financiado](#3.2.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.2.3 Proyectos con el mayor monto promedio por donante](#3.2.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.2.4 Proyectos con la mayor donación individual](#3.2.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.3 Donantes y sus donaciones](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.3.1 Donantes con el mayor número de donaciones](#3.3.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.3.2 Donantes que han aportado el mayor monto total](#3.3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.3.3 Donantes con el mayor monto promedio por donación](#3.3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.3.4 Donantes con la mayor donación individual](#3.3.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.4 Montos de las donaciones por año, mes, día y hora](#3.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.5 Donaciones opcionales y donaciones de docentes](#3.5)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.5.1 Número y monto promedio de las donaciones opcionales](#3.5.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.5.2 Número y monto promedio de las donaciones de docentes](#3.5.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.6 ¿Qué estado ha recibido el mayor monto de donaciones?](#3.6)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.7 ¿Qué estado recibe el mayor monto promedio de donaciones?](#3.7)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.8 Estados y el total de donaciones recibidas](#3.8)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.9 Donaciones de California a lo largo del tiempo](#3.9)
#
# [4. Exploración de los docentes](#4)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.1 Resumen de los datos de los docentes](#4.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.2 ¿Quiénes fueron los primeros docentes en DonorsChoose?](#4.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.3 Crecimiento del número de docentes a lo largo de los años](#4.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.4 Distribución de los prefijos de los docentes](#4.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.5 Serie temporal de los docentes que publicaron su primer proyecto](#4.5)
#
# [5. Exploración de las escuelas](#5)
# &thinsp;&thinsp;&thinsp;&thinsp; [5.1 Resumen de los datos de las escuelas](#5.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [5.2 ¿Qué tipos de escuelas según el área metropolitana publican proyectos? (y principales estados y ciudades)](#5.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [5.3 Distribución del porcentaje de estudiantes con almuerzo gratuito](#5.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [5.4 ¿Qué tipos de escuelas son mayoría?](#5.4)
#
# [6. Exploración de los recursos](#6)
# &thinsp;&thinsp;&thinsp;&thinsp; [6.1 Resumen de los datos de los recursos](#6.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [6.2 ¿Qué artículos son los más populares en DonorsChoose?](#6.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [6.3 ¿Cuáles son los artículos más costosos?](#6.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [6.4 ¿Cuáles son los proveedores más populares y cuál es el costo promedio asociado a ellos?](#6.4)
#
# [7. Exploración de los proyectos](#7)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.1 Resumen de los datos de los proyectos](#7.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.2 Categorías, subcategorías y categorías de recursos más frecuentes](#7.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.3 Tipo y estado de los proyectos](#7.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.4 Fecha de publicación y fecha de financiación](#7.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.5 Trimestre de publicación y trimestre de financiación](#7.5)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.6 ¿En qué mes se publican más proyectos?](#7.6)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.7 ¿Está aumentando el número de proyectos?](#7.7)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.8 ¿En qué año y mes el costo de los proyectos es más alto?](#7.8)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.9 ¿En qué año y categoría de grado el costo de los proyectos es mayor?](#7.9)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.10 ¿Para qué categoría de grado y categoría de recursos el costo de los proyectos es más alto?](#7.10)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.11 Estado de los proyectos por año](#7.11)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.12 Duración de los proyectos financiados con éxito](#7.12)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.13 Estado de los proyectos por estado](#7.13)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.14 Costo promedio de los proyectos según el tipo de área metropolitana y la categoría de recursos](#7.14)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.15 Costo promedio de los proyectos según el tipo de área metropolitana y el nivel educativo](#7.15)
#
# [8. Análisis de texto de los proyectos](#8)
# &thinsp;&thinsp;&thinsp;&thinsp; [8.1 Limpieza del texto](#8.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [8.2 Análisis de bolsa de palabras (Bag of Words)](#8.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.1 Palabras y n-gramas más utilizados por los docentes en todos los ensayos](#8.2.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.2 Palabras y n-gramas más utilizados en diferentes estados](#8.2.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.3 Contexto de "Mis estudiantes son..."](#8.2.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.4 Contexto de "Mis estudiantes necesitan..."](#8.2.4)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.5 Título del proyecto: palabras clave más utilizadas](#8.2.5)
#
# [9. Comprensión y comparación de las características de los proyectos](#9)
# &thinsp;&thinsp;&thinsp;&thinsp; [9.1 Proyectos vencidos vs. proyectos financiados con éxito](#9.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [9.2 Proyectos con menor duración de financiación vs. mayor duración](#9.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [9.3 Proyectos con un solo donante vs. múltiples donantes](#9.3)
#
# <br>
#
# ## <a id="1">1. Preparación del conjunto de datos</a>
#
# Importemos las bibliotecas necesarias y carguemos el conjunto de datos.

# %%
# !pip install wordcloud

# %%
# !pip install folium

# %%
# Importar las bibliotecas necesarias
from plotly.offline import init_notebook_mode, iplot
from wordcloud import WordCloud
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import date

from plotly import tools
from datetime import date
import pandas as pd
import numpy as np
import seaborn as sns
import random
import warnings
import operator

# Suprimir mensajes de advertencia
warnings.filterwarnings("ignore")

# Inicializar Plotly para su uso en Jupyter Notebook
init_notebook_mode(connected=True)

# Ruta donde se encuentran los archivos de datos
path = "../Practica05//"

# Cargar los conjuntos de datos
donors_df = pd.read_csv(path + "Donors.csv")
donations_df = pd.read_csv(path + "Donations.csv")
teachers_df = pd.read_csv(path + "Teachers.csv")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %% [markdown]
# ## <a id="2">2. Exploración de los Donantes</a>
#
# El conjunto de datos de donantes contiene información sobre cada persona que ha realizado al menos una donación en DonorsChoose, como su ciudad, estado, código postal y si es docente o no.
#
# ## <a id="2.1">2.1 Resumen de los Donantes</a>
#
# A continuación, observaremos una vista previa de las primeras filas del conjunto de datos de donantes

# %%
###### Total de filas
# donors_df.shape

###### Total de ciudades
# len(donors_df['Donor City'].value_counts())

# Donantes con más de una donación
# t = donations_df['Donor ID'].value_counts().to_frame()
# len(t[t['Donor ID'] > 1])

donors_df.head(3)
# Out:
#                            Donor ID   Donor City Donor State Donor Is Teacher  \
# 0  f09a01dbe56dc9948be4bcd62708745c        Tampa     Florida               No
# 1  899dec40fe7fe633a0f1e8b8f3dca99a  Kansas City    Missouri               No
# 2  a77a4e308b7d89cbefe8c99064f03454   Waxahachie       Texas               No
#
#   Donor Zip
# 0       336
# 1       641
# 2       751

# %% [markdown]
# Hay un total de **2,122,640** donantes registrados en **DonorsChoose** hasta abril de 2018. Estos donantes pertenecen a **15,204 ciudades diferentes** de **Estados Unidos** y de algunos otros países. De este enorme número de donantes, solo **552,941 (es decir, aproximadamente el 26%)** han realizado más de una donación. Uno de los principales objetivos del desafío **Data Science for Good** es encontrar información relevante y generar recomendaciones que inspiren a los donantes a volver a donar. Hay alrededor de **1,471,613** donantes que han realizado solo una donación, por lo que **DonorsChoose** tiene la oportunidad de motivar a estas personas para que realicen una segunda contribución.
#
# ## 2.2 Donantes de cada estado
#
# ### 2.2.1 Número de donantes por estado

# %%
import folium
from io import StringIO
import pandas as pd

statesll = StringIO("""State,Latitude,Longitude
Alabama,32.806671,-86.791130
Alaska,61.370716,-152.404419
Arizona,33.729759,-111.431221
Arkansas,34.969704,-92.373123
California,36.116203,-119.681564
Colorado,39.059811,-105.311104
Connecticut,41.597782,-72.755371
Delaware,39.318523,-75.507141
District of Columbia,38.897438,-77.026817
Florida,27.766279,-81.686783
Georgia,33.040619,-83.643074
Hawaii,21.094318,-157.498337
Idaho,44.240459,-114.478828
Illinois,40.349457,-88.986137
Indiana,39.849426,-86.258278
Iowa,42.011539,-93.210526
Kansas,38.526600,-96.726486
Kentucky,37.668140,-84.670067
Louisiana,31.169546,-91.867805
Maine,44.693947,-69.381927
Maryland,39.063946,-76.802101
Massachusetts,42.230171,-71.530106
Michigan,43.326618,-84.536095
Minnesota,45.694454,-93.900192
Mississippi,32.741646,-89.678696
Missouri,38.456085,-92.288368
Montana,46.921925,-110.454353
Nebraska,41.125370,-98.268082
Nevada,38.313515,-117.055374
New Hampshire,43.452492,-71.563896
New Jersey,40.298904,-74.521011
New Mexico,34.840515,-106.248482
New York,42.165726,-74.948051
North Carolina,35.630066,-79.806419
North Dakota,47.528912,-99.784012
Ohio,40.388783,-82.764915
Oklahoma,35.565342,-96.928917
Oregon,44.572021,-122.070938
Pennsylvania,40.590752,-77.209755
Rhode Island,41.680893,-71.511780
South Carolina,33.856892,-80.945007
South Dakota,44.299782,-99.438828
Tennessee,35.747845,-86.692345
Texas,31.054487,-97.563461
Utah,40.150032,-111.862434
Vermont,44.045876,-72.710686
Virginia,37.769337,-78.169968
Washington,47.400902,-121.490494
West Virginia,38.491226,-80.954453
Wisconsin,44.268543,-89.616508
Wyoming,42.755966,-107.302490""")

# Contar donantes por estado
tempdf = donors_df['Donor State'].value_counts()
t1 = pd.DataFrame()
t1['Donor State'] = tempdf.index
t1['Donor Count'] = tempdf.values

# Leer coordenadas y hacer merge
sdf = pd.read_csv(statesll).rename(columns={'State': 'Donor State'})
sdf = sdf.merge(t1, on='Donor State', how='inner')

# Crear mapa
map4 = folium.Map(
    location=[39.50, -98.35],
    tiles='CartoDB dark_matter',
    zoom_start=4
)

# Agregar círculos con estilo similar al ejemplo
for j, rown in sdf.iterrows():
    rown = list(rown)
    donantes = float(rown[3])
    
    # Calcular radio
    radius = max(10, min(int(donantes / 100), 80))
    
    folium.CircleMarker(
        [float(rown[1]), float(rown[2])],
        popup="<b>Estado:</b> " + str(rown[0]) +
              "<br><b>Donantes:</b> " + "{:,}".format(int(donantes)),
        radius=radius,
        color='#be0eff',           # Color del borde (morado brillante)
        weight=3,                  # Grosor del borde (más visible)
        fill=True,
        fill_color='#be0eff',      # Mismo color que el borde
        fill_opacity=0.3           # Muy transparente (como el ejemplo)
    ).add_to(map4)

map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
def bar_hor(df, col, title, color, w=None, h=None, lm=0, limit=100, return_trace=False, rev=False):
    cnt_srs = df[col].value_counts()
    yy = cnt_srs.head(limit).index[::-1]
    xx = cnt_srs.head(limit).values[::-1]

    if rev:
        yy = cnt_srs.tail(limit).index[::-1]
        xx = cnt_srs.tail(limit).values[::-1]

    trace = go.Bar(y=yy, x=xx, orientation='h',
                   marker=dict(color=color))

    if return_trace:
        return trace

    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    fig = go.Figure(data=[trace], layout=layout)
    iplot(fig)


def bar_hor_noagg(x, y, title, color, w=None, h=None, lm=0, limit=100, rt=False):
    trace = go.Bar(y=x, x=y, orientation='h',
                   marker=dict(color=color))

    if rt:
        return trace

    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    fig = go.Figure(data=[trace], layout=layout)
    iplot(fig)


def bar_ver_noagg(x, y, title, color, w=None, h=None, lm=0, rt=False):
    trace = go.Bar(y=y, x=x,
                   marker=dict(color=color))

    if rt:
        return trace

    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    fig = go.Figure(data=[trace], layout=layout)
    iplot(fig)


trace1 = bar_hor(
    donors_df,
    'Donor City',
    "Ciudades con el mayor número de donantes",
    '#c2d2ed',
    500, 400, 200,
    limit=10,
    return_trace=True
)

trace2 = bar_hor(
    donors_df,
    'Donor State',
    "Estados con el mayor número de donantes",
    '#c2d2ed',
    500, 400, 200,
    limit=10,
    return_trace=True
)

trace4 = bar_hor(
    donors_df,
    'Donor State',
    "Estados con el menor número de donantes",
    '#c2d2ed',
    600, 400, 200,
    limit=10,
    return_trace=True,
    rev=True
)

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Estados con el mayor número de donantes',
        'Estados con el menor número de donantes'
    ]
)

fig.append_trace(trace2, 1, 1)
fig.append_trace(trace4, 1, 2)

fig['layout'].update(height=400, showlegend=False)
iplot(fig)

# %% [markdown]
# > - **California**, al ser el estado con la mayor población, también cuenta con la mayor cantidad de donantes registrados, con cerca de **300,000 donantes**. **San Francisco** y **Los Ángeles** son las principales ciudades de California donde se concentra el mayor número de donantes. Asimismo, California es el estado con el mayor número de escuelas y proyectos.
# >
# > - **Nueva York**, **Texas** y **Florida**, con aproximadamente **137,000**, **134,000** y **108,000** donantes, respectivamente, son los otros estados con la mayor cantidad de donantes. Las principales ciudades son **Nueva York**, **Miami**, **Tampa**, **Houston** y **Dallas**, donde se concentra la mayor parte de los donantes.
# >
# > - **Dakota del Norte**, **Dakota del Sur**, **Vermont** y **Wyoming** son los estados con el menor número de donantes, con menos de **4,000** cada uno. Además, existe una categoría denominada **"Others" (Otros)** en los datos de los estados, que probablemente agrupa a donantes docentes o a donantes provenientes de otros países.
# >
# > - Considerando todas las ciudades de Estados Unidos, las tres con mayor número de donantes son **Chicago** (aproximadamente **35 mil donantes**), **Nueva York** (aproximadamente **27 mil**) y **Brooklyn** (aproximadamente **22 mil**). Las ciudades californianas de **San Francisco** y **Los Ángeles** ocupan el cuarto y quinto lugar, con alrededor de **18 mil** y **16 mil** donantes, respectivamente.
#
# ## <a>Conjunto de datos ajustado por población</a>
#
# Los estados que encabezan las gráficas anteriores son, en gran medida, los que poseen una población más alta. Por ello, resulta interesante analizar el **número de donantes por cada 100,000 habitantes** en cada estado.
#
# Para este análisis se ha incorporado un conjunto de datos ajustado por población, que incluye la población de cada estado de Estados Unidos correspondiente al año **2013**.
#
# **Conjunto de datos de población:** http://www.enchantedlearning.com/usa/states/population.shtml
#
# ## <a id="2.3">2.3 Estados con la mayor **proporción de donantes respecto a la población**</a>

# %%
# Población estimada por estado (Censo de EE. UU., 2013)
census_2013 = {
    'Mississippi': 2991207, 'Iowa': 3090416, 'Oklahoma': 3850568,
    'Delaware': 925749, 'Minnesota': 5420380, 'Alaska': 735132,
    'Illinois': 12882135, 'Arkansas': 2959373, 'New Mexico': 2085287,
    'Indiana': 6570902, 'Maryland': 5928814, 'Louisiana': 4625470,
    'Texas': 26448193, 'Wyoming': 582658, 'Arizona': 6626624,
    'Wisconsin': 5742713, 'Michigan': 9895622, 'Kansas': 2893957,
    'Utah': 2900872, 'Virginia': 8260405, 'Oregon': 3930065,
    'Connecticut': 3596080, 'New York': 19651127,
    'California': 38332521, 'Massachusetts': 6692824,
    'West Virginia': 1854304, 'South Carolina': 4774839,
    'New Hampshire': 1323459, 'Vermont': 626630,
    'Georgia': 9992167, 'North Dakota': 723393,
    'Pennsylvania': 12773801, 'Florida': 19552860,
    'Hawaii': 1404054, 'Kentucky': 4395295,
    'Rhode Island': 1051511, 'Nebraska': 1868516,
    'Missouri': 6044171, 'Ohio': 11570808,
    'Alabama': 4833722, 'South Dakota': 844877,
    'Colorado': 5268367, 'Idaho': 1612136,
    'New Jersey': 8899339, 'Washington': 6971406,
    'North Carolina': 9848060, 'Tennessee': 6495978,
    'Montana': 1015165, 'District of Columbia': 646449,
    'Nevada': 2790136, 'Maine': 1328302
}

# Número de donantes por estado
donors_from_states = dict(donors_df['Donor State'].value_counts())

# Calcular el número de donantes por cada 100 000 habitantes
don_pop = {}
for state, don in donors_from_states.items():
    if state not in census_2013:
        continue
    don_pop[state] = float(don) * 100000 / census_2013[state]

import operator

# Ordenar los estados según la proporción de donantes
don_pop = sorted(don_pop.items(), key=operator.itemgetter(1), reverse=True)

xx = [x[0] for x in don_pop][1:]
yy = [x[1] for x in don_pop][1:]

trace2 = go.Bar(
    x=xx,
    y=yy,
    name='Donantes por población',
    marker=dict(color='green'),
    opacity=0.3
)

data = [trace2]

layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-0.1, y=1.2)),
    margin=dict(b=120),
    title='Estados con la mayor proporción de donantes respecto a la población'
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')

# %% [markdown]
# > - Se obtiene un resultado interesante al analizar la proporción de donantes respecto a la población. Los estados de **Carolina del Sur** (población = **4,774,839**), **Massachusetts** (población = **6,692,824**) y **Connecticut** (población = **3,596,080**) presentan la mayor proporción de donantes y, por tanto, el mayor número de donantes por cada **100,000 habitantes**. En particular:
# >   - **Carolina del Sur:** 985 donantes por cada 100,000 habitantes.
# >   - **Massachusetts:** 907 donantes por cada 100,000 habitantes.
# >   - **Connecticut:** 878 donantes por cada 100,000 habitantes.
# >
# > - Por el contrario, **Wyoming**, **Nebraska** y **Nuevo México** registran la menor proporción de donantes, con **285**, **335** y **363** donantes por cada **100,000 habitantes**, respectivamente.
# >
# > - Aunque **Texas** es uno de los estados con el mayor número absoluto de donantes, su proporción de donantes respecto a la población es relativamente menor, con **508 donantes por cada 100,000 habitantes**.
#
# ## <a id="2.4">2.4 Visualización de la ubicación de los donantes</a>
#
# ## <a id="2.4.1">2.4.1 Ubicación de los donantes en California</a>

# %%
import folium
from folium import plugins
calcit = StringIO(u"""Name,Latitude,Longitude,Total Donors,Color,Size
Los Angeles,34.052233,-118.243686,"17,922.000000",#0061ff,10
San Francisco,37.774931,-122.419417,"16,553.000000",#0061ff,10
San Diego,32.715328,-117.157256,"9,072.000000",#0061ff,10
San Jose,37.339386,-121.894956,"7,674.000000",#0061ff,10
Oakland,37.804364,-122.271114,"6,783.000000",#0061ff,10
Sacramento,38.581572,-121.494400,"4,701.000000",#0061ff,10
Bakersfield,35.373292,-119.018711,"3,758.000000",#0061ff,10
Long Beach,33.768322,-118.195617,"3,120.000000",#0061ff,10
Berkeley,37.871592,-122.272747,"2,898.000000",#0061ff,10
Irvine,33.683947,-117.794694,"2,765.000000",#0061ff,10
Fremont,37.548269,-121.988572,"2,716.000000",#0061ff,10
Walnut Creek,37.910078,-122.065183,"2,255.000000",#0061ff,10
Huntington Beach,33.660297,-117.999225,"2,185.000000",#0061ff,10
Murrieta,33.553914,-117.213922,"1,982.000000",#0061ff,10
Pleasanton,37.662431,-121.874678,"1,970.000000",#0061ff,10
Torrance,33.83585,-118.340628,"1,957.000000",#0061ff,10
San Mateo,37.562992,-122.325525,"1,956.000000",#0061ff,10
Santa Monica,34.019453,-118.491192,"1,780.000000",#0061ff,10
Livermore,37.681875,-121.768008,"1,776.000000",#0061ff,10
Santa Rosa,38.440467,-122.714431,"1,752.000000",#0061ff,10
Concord,37.977978,-122.031072,"1,623.000000",#0061ff,10
Alameda,37.765206,-122.241636,"1,548.000000",#0061ff,10
Fresno,36.746842,-119.772586,"1,543.000000",#0061ff,10
San Ramon,37.779928,-121.978014,"1,533.000000",#0061ff,10
Anaheim,33.835292,-117.914503,"1,475.000000",#0061ff,10
Pasadena,34.147786,-118.144517,"1,429.000000",#0061ff,10
Glendale,34.142508,-118.255075,"1,427.000000",#0061ff,10
Riverside,33.95335,-117.396156,"1,425.000000",#0061ff,10
Sunnyvale,37.368831,-122.036350,"1,406.000000",#0061ff,10
Chula Vista,32.640053,-117.084197,"1,398.000000",#0061ff,10
Mountain View,37.386053,-122.083850,"1,398.000000",#0061ff,10
Elk Grove,38.4088,-121.371617,"1,397.000000",#0061ff,10
Santa Clarita,34.391664,-118.542586,"1,382.000000",#0061ff,10
Burbank,34.180839,-118.308967,"1,357.000000",#0061ff,10
Redwood City,37.485214,-122.236356,"1,323.000000",#0061ff,10
Chico,39.728494,-121.837478,"1,322.000000",#0061ff,10
Whittier,33.979178,-118.032844,"1,280.000000",#0061ff,10
Corona,33.875294,-117.566439,"1,239.000000",#0061ff,10
Santa Clara,37.354108,-121.955236,"1,233.000000",#0061ff,10
Orange,33.787794,-117.853111,"1,229.000000",#0061ff,10
Palo Alto,37.441883,-122.143019,"1,219.000000",#0061ff,10
Hayward,37.668819,-122.080797,"1,162.000000",#0061ff,10
Oceanside,33.195869,-117.379483,"1,157.000000",#0061ff,10
Fullerton,33.870292,-117.925339,"1,151.000000",#0061ff,10
San Rafael,37.973536,-122.531086,"1,136.000000",#0061ff,10
Folsom,38.677958,-121.176058,"1,125.000000",#0061ff,10
Simi Valley,34.269447,-118.781483,"1,069.000000",#0061ff,10
Escondido,33.119208,-117.086422,"1,062.000000",#0061ff,10
Santa Ana,33.745572,-117.867833,"1,054.000000",#0061ff,10
Redondo Beach,33.849183,-118.388408,"1,048.000000",#34ef6c,8
Stockton,37.957703,-121.290781,"1,041.000000",#34ef6c,8
Santa Cruz,36.974117,-122.030797,"1,029.000000",#34ef6c,8
Culver City,34.021122,-118.396467,"1,019.000000",#34ef6c,8
Salinas,36.677736,-121.655500,"1,017.000000",#34ef6c,8
Martinez,38.019367,-122.134133,975.000000,#34ef6c,8
Santa Barbara,34.420831,-119.698189,936.000000,#34ef6c,8
San Leandro,37.724931,-122.156078,929.000000,#34ef6c,8
Ventura,34.274639,-119.229006,922.000000,#34ef6c,8
Roseville,38.752122,-121.288006,888.000000,#34ef6c,8
Yorba Linda,33.888625,-117.813111,888.000000,#34ef6c,8
Costa Mesa,33.641133,-117.918669,887.000000,#34ef6c,8
San Marcos,33.143372,-117.166144,866.000000,#34ef6c,8
Brentwood,34.057361,-118.480511,853.000000,#34ef6c,8
South San Francisco,37.654656,-122.407750,841.000000,#34ef6c,8
Modesto,37.639097,-120.996878,837.000000,#34ef6c,8
Temecula,33.493639,-117.148364,837.000000,#34ef6c,8
Novato,38.107419,-122.569703,831.000000,#34ef6c,8
Carlsbad,33.158092,-117.350594,822.000000,#34ef6c,8
Mission Viejo,33.600022,-117.671994,817.000000,#34ef6c,8
Brea,33.916681,-117.900061,802.000000,#34ef6c,8
Garden Grove,33.773906,-117.941447,792.000000,#34ef6c,8
Dublin,37.702153,-121.935792,784.000000,#34ef6c,8
El Cajon,32.794772,-116.962528,783.000000,#34ef6c,8
Menlo Park,37.453828,-122.182186,768.000000,#34ef6c,8
Fairfield,38.249358,-122.039967,751.000000,#34ef6c,8
Pleasant Hill,37.947978,-122.060797,725.000000,#34ef6c,8
Napa,38.297539,-122.286864,711.000000,#34ef6c,8
Richmond,37.935758,-122.347750,707.000000,#34ef6c,8
Los Altos,33.796331,-118.118119,703.000000,#34ef6c,8
Daly City,37.687925,-122.470208,702.000000,#34ef6c,8
West Covina,34.068622,-117.938953,688.000000,#34ef6c,8
Lafayette,37.885758,-122.118019,660.000000,#34ef6c,8
La Mesa,32.767828,-117.023083,649.000000,#34ef6c,8
Milpitas,37.428272,-121.906625,649.000000,#34ef6c,8
Carson,33.831406,-118.282017,647.000000,#34ef6c,8
Camarillo,34.216394,-119.037603,643.000000,#34ef6c,8
Petaluma,38.232417,-122.636653,629.000000,#34ef6c,8
Newport Beach,33.618911,-117.928947,626.000000,#34ef6c,8
Pacifica,37.613825,-122.486919,619.000000,#34ef6c,8
Gilroy,37.005783,-121.568275,618.000000,#34ef6c,8
Encinitas,33.036986,-117.291983,607.000000,#34ef6c,8
El Segundo,33.919181,-118.416464,595.000000,#34ef6c,8
Downey,33.940014,-118.132569,592.000000,#34ef6c,8
Rancho Palos Verdes,33.744461,-118.387017,592.000000,#34ef6c,8
San Clemente,33.426972,-117.611992,589.000000,#34ef6c,8
Vacaville,38.356578,-121.987744,584.000000,#34ef6c,8
Chino Hills,33.989819,-117.732586,583.000000,#34ef6c,8
Campbell,37.287164,-121.949958,580.000000,#34ef6c,8
Mill Valley,37.906036,-122.544975,578.000000,#34ef6c,8
El Cerrito,37.916133,-122.310764,576.000000,#f2ae93,6
Emeryville,37.831317,-122.285247,572.000000,#f2ae93,6
Thousand Oaks,34.107231,-118.057847,572.000000,#f2ae93,6
Burlingame,37.584103,-122.366083,570.000000,#f2ae93,6
Antioch,38.004922,-121.805789,568.000000,#f2ae93,6
Beverly Hills,34.073619,-118.400356,568.000000,#f2ae93,6
Lakewood,33.853628,-118.133956,560.000000,#f2ae93,6
Manhattan Beach,33.884736,-118.410908,557.000000,#f2ae93,6
Lancaster,34.686786,-118.154164,551.000000,#f2ae93,6
Oxnard,34.197506,-119.177053,539.000000,#f2ae93,6
San Carlos,37.507158,-122.260522,527.000000,#f2ae93,6
Rocklin,38.790733,-121.235783,526.000000,#f2ae93,6
Placentia,33.872236,-117.870336,520.000000,#f2ae93,6
Cupertino,37.322997,-122.032183,516.000000,#f2ae93,6
Tustin,33.74585,-117.826167,508.000000,#f2ae93,6
Hermosa Beach,33.862236,-118.399519,507.000000,#f2ae93,6
Rancho Cordova,38.589072,-121.302728,501.000000,#f2ae93,6
Fountain Valley,33.709186,-117.953669,498.000000,#f2ae93,6
Cypress,37.320531,-121.962242,497.000000,#f2ae93,6
Union City,37.593392,-122.043831,494.000000,#f2ae93,6
Morgan Hill,37.1305,-121.654389,488.000000,#f2ae93,6
Vallejo,38.104086,-122.256636,485.000000,#f2ae93,6
Alhambra,34.095286,-118.127014,474.000000,#f2ae93,6
Lake Forest,33.646967,-117.689217,465.000000,#f2ae93,6
Rancho Cucamonga,34.1064,-117.593108,463.000000,#f2ae93,6
Vista,33.200036,-117.242536,463.000000,#f2ae93,6
Fontana,34.092233,-117.435047,459.000000,#f2ae93,6
Moreno Valley,33.942467,-117.229672,455.000000,#f2ae93,6
Hawthorne,33.916403,-118.352575,450.000000,#f2ae93,6
Covina,34.090008,-117.890339,443.000000,#f2ae93,6
San Luis Obispo,35.282753,-120.659617,434.000000,#f2ae93,6
Newark,37.529658,-122.040239,433.000000,#f2ae93,6
Inglewood,33.961681,-118.353131,432.000000,#f2ae93,6
Oakley,37.997422,-121.712453,430.000000,#f2ae93,6
Tracy,37.73965,-121.425222,428.000000,#f2ae93,6
Redding,40.586539,-122.391675,424.000000,#f2ae93,6
Glendora,34.136119,-117.865339,423.000000,#f2ae93,6
San Bruno,37.630489,-122.411083,423.000000,#f2ae93,6
Davis,38.544906,-121.740517,417.000000,#f2ae93,6
Westminster,33.751342,-117.993992,413.000000,#f2ae93,6
Pittsburg,38.027975,-121.884681,412.000000,#f2ae93,6
Palmdale,34.579433,-118.116461,408.000000,#f2ae93,6
Visalia,36.330228,-119.292058,406.000000,#f2ae93,6
Poway,32.962822,-117.035864,403.000000,#f2ae93,6
Santa Maria,34.953033,-120.435719,403.000000,#f2ae93,6
Upland,34.097511,-117.648389,396.000000,#f2ae93,6
Laguna Niguel,33.522525,-117.707553,393.000000,#f2ae93,6
La Mirada,33.917236,-118.012008,392.000000,#f2ae93,6
South Pasadena,34.116119,-118.150350,391.000000,#f2ae93,6
Cerritos,33.858347,-118.064786,383.000000,#f2ae93,6
Lodi,38.134147,-121.272219,380.000000,#f2ae93,6
Ontario,34.063344,-117.650889,380.000000,#bab7b6,4
Lincoln,38.891564,-121.293008,376.000000,#bab7b6,4
Buena Park,33.867514,-117.998117,375.000000,#bab7b6,4
Rancho Santa Margarita,33.640856,-117.603103,373.000000,#bab7b6,4
Santee,32.838383,-116.973917,373.000000,#bab7b6,4
Sonoma,38.291858,-122.458036,372.000000,#bab7b6,4
Monrovia,34.144428,-118.001947,371.000000,#bab7b6,4
Albany,37.886869,-122.297747,368.000000,#bab7b6,4
La Habra,33.931958,-117.946172,366.000000,#bab7b6,4
San Pablo,37.962147,-122.345525,366.000000,#bab7b6,4
Belmont,37.520214,-122.275800,364.000000,#bab7b6,4
Pomona,34.055228,-117.752306,364.000000,#bab7b6,4
Gardena,33.88835,-118.308961,363.000000,#bab7b6,4
Arcadia,34.139728,-118.035344,361.000000,#bab7b6,4
Clovis,36.825228,-119.702919,360.000000,#bab7b6,4
Orinda,37.877147,-122.179689,358.000000,#bab7b6,4
Manteca,37.797428,-121.216053,357.000000,#bab7b6,4
Citrus Heights,38.707125,-121.281061,355.000000,#bab7b6,4
Redlands,34.055569,-117.182539,353.000000,#bab7b6,4
Aliso Viejo,33.575,-117.725556,345.000000,#bab7b6,4
Eureka,40.802072,-124.163672,338.000000,#bab7b6,4
West Hollywood,34.090008,-118.361744,337.000000,#bab7b6,4
Auburn,38.896564,-121.076889,335.000000,#bab7b6,4
Saratoga,37.263833,-122.023014,331.000000,#bab7b6,4
Turlock,37.494658,-120.846594,327.000000,#bab7b6,4
Chino,34.012236,-117.688944,325.000000,#bab7b6,4
Diamond Bar,34.028622,-117.810336,324.000000,#bab7b6,4
South Gate,33.954736,-118.212017,319.000000,#bab7b6,4
San Bernardino,34.108344,-117.289764,318.000000,#bab7b6,4
Claremont,34.096675,-117.719778,316.000000,#bab7b6,4
Calabasas,34.138333,-118.660833,298.000000,#bab7b6,4
Los Alamitos,33.803072,-118.072564,297.000000,#bab7b6,4
Agoura Hills,34.153339,-118.761675,295.000000,#bab7b6,4
San Gabriel,34.096111,-118.105833,295.000000,#bab7b6,4
Paso Robles,35.632278,-120.664186,292.000000,#bab7b6,4
Norwalk,33.902236,-118.081733,286.000000,#bab7b6,4
Indio,33.720578,-116.215561,284.000000,#bab7b6,4
Moorpark,34.144897,-118.268742,284.000000,#bab7b6,4
Monterey,36.600239,-121.894675,275.000000,#bab7b6,4
Arroyo Grande,35.118586,-120.590725,274.000000,#bab7b6,4
San Dimas,34.106675,-117.806725,274.000000,#bab7b6,4
La Puente,34.020011,-117.949508,273.000000,#bab7b6,4
West Sacramento,38.580461,-121.530233,273.000000,#bab7b6,4
Rohnert Park,38.339636,-122.701097,269.000000,#bab7b6,4
Monterey Park,34.062511,-118.122847,266.000000,#bab7b6,4
Laguna Hills,33.599722,-117.699444,260.000000,#bab7b6,4
Watsonville,36.910231,-121.756894,259.000000,#bab7b6,4
Clayton,37.941033,-121.935792,256.000000,#bab7b6,4
Hemet,33.747519,-116.971967,256.000000,#bab7b6,4
La Verne,34.100842,-117.767836,255.000000,#bab7b6,4
Ukiah,39.150172,-123.207783,255.000000,#f477d7,2
Palm Desert,33.722244,-116.374456,251.000000,#f477d7,2
Atascadero,35.489417,-120.670725,241.000000,#f477d7,2
Menifee,33.678333,-117.166944,241.000000,#f477d7,2
Lompoc,34.63915,-120.457942,240.000000,#f477d7,2
Merced,37.302164,-120.482967,240.000000,#f477d7,2
Sebastopol,38.402136,-122.823881,237.000000,#f477d7,2
Lake Elsinore,33.668078,-117.327261,236.000000,#f477d7,2
Millbrae,37.598547,-122.387194,234.000000,#f477d7,2
Yuba City,39.140447,-121.616911,231.000000,#f477d7,2
Woodland,38.678517,-121.773297,228.000000,#f477d7,2
Bellflower,33.881683,-118.117011,227.000000,#f477d7,2
Grass Valley,39.219061,-121.061061,227.000000,#f477d7,2
Seal Beach,33.741406,-118.104786,227.000000,#f477d7,2
Walnut,34.020289,-117.865339,227.000000,#f477d7,2
Montebello,34.016506,-118.113753,225.000000,#f477d7,2
Yucaipa,34.033625,-117.043086,225.000000,#f477d7,2
Hanford,36.32745,-119.645683,224.000000,#f477d7,2
Goleta,34.435828,-119.827639,221.000000,#f477d7,2
Hesperia,34.426389,-117.300878,221.000000,#f477d7,2
Laguna Beach,33.542247,-117.783111,221.000000,#f477d7,2
Ridgecrest,35.622456,-117.670897,218.000000,#f477d7,2
Galt,38.254636,-121.299947,217.000000,#f477d7,2
Victorville,34.536108,-117.291158,217.000000,#f477d7,2
San Juan Capistrano,33.501692,-117.662550,209.000000,#f477d7,2
Atwater,37.347717,-120.609083,208.000000,#f477d7,2
Palm Springs,33.830297,-116.545292,208.000000,#f477d7,2
Azusa,34.133619,-117.907564,203.000000,#f477d7,2
Hercules,38.017144,-122.288581,202.000000,#f477d7,2
Sonora,37.984092,-120.382139,199.000000,#f477d7,2
Beaumont,33.929461,-116.977247,198.000000,#f477d7,2
Half Moon Bay,37.463553,-122.428586,197.000000,#f477d7,2
Hollister,36.852453,-121.401603,196.000000,#f477d7,2
Westlake Village,34.145839,-118.805647,194.000000,#f477d7,2
Pico Rivera,33.983069,-118.096736,190.000000,#f477d7,2
Pinole,38.004367,-122.298858,186.000000,#f477d7,2
Compton,33.89585,-118.220072,185.000000,#f477d7,2
Sausalito,37.859094,-122.485250,183.000000,#f477d7,2
La Quinta,33.646692,-116.310008,181.000000,#f477d7,2
Dana Point,33.466972,-117.698108,175.000000,#f477d7,2
Rialto,34.1064,-117.370325,172.000000,#f477d7,2
Perris,33.782519,-117.228647,171.000000,#f477d7,2
Arcata,40.866517,-124.082839,168.000000,#f477d7,2
Pacific Grove,36.617736,-121.916622,168.000000,#f477d7,2
Lomita,33.792239,-118.315072,167.000000,#f477d7,2
San Fernando,34.281947,-118.438972,165.000000,#f477d7,2
South Lake Tahoe,38.939925,-119.977186,163.000000,#f477d7,2
El Monte,34.068622,-118.027567,158.000000,#f477d7,2
Scotts Valley,37.051061,-122.014683,158.000000,#f477d7,2
Tehachapi,35.132189,-118.448975,157.000000,#f477d7,2
Baldwin Park,34.085286,-117.960897,156.000000,#f477d7,2
Marina,36.684403,-121.802172,155.000000,#f477d7,2
Rosemead,34.080564,-118.072847,155.000000,#f477d7,2
Placerville,38.729625,-120.798547,151.000000,#f477d7,2
Highland,34.128344,-117.208650,148.000000,#f477d7,2
Lawndale,33.887236,-118.352575,143.000000,#f477d7,2
Oroville,39.513775,-121.556358,142.000000,#f477d7,2
Seaside,33.819361,-118.366647,142.000000,#f477d7,2
Wildomar,33.598914,-117.280036,142.000000,#f477d7,2
Duarte,34.13945,-117.977286,141.000000,#f477d7,2
Huntington Park,33.981681,-118.225072,141.000000,#f477d7,2
Larkspur,37.934092,-122.535253,139.000000,#f477d7,2
Del Mar,32.959489,-117.265314,138.000000,#f477d7,2
Winters,38.524906,-121.970803,138.000000,#f477d7,2
Red Bluff,40.178489,-122.235831,137.000000,#f477d7,2
Cathedral City,33.779742,-116.465292,136.000000,#f9e84a,1
Ojai,34.44805,-119.242889,136.000000,#f9e84a,1
Coronado,32.685886,-117.183089,134.000000,#f9e84a,1
Lynwood,33.930292,-118.211461,134.000000,#f9e84a,1
Temple City,34.107231,-118.057847,132.000000,#f9e84a,1
Bell,33.977514,-118.187017,124.000000,#f9e84a,1
Sierra Madre,34.161672,-118.052847,119.000000,#f9e84a,1
Nevada City,39.261561,-121.016058,118.000000,#f9e84a,1
National City,32.678108,-117.099197,117.000000,#f9e84a,1
Ceres,37.594933,-120.957711,116.000000,#f9e84a,1
Solana Beach,32.991156,-117.271147,115.000000,#f9e84a,1
La Palma,33.846403,-118.046731,114.000000,#f9e84a,1
Healdsburg,38.610467,-122.869161,110.000000,#f9e84a,1
Ripon,37.739453,-121.135414,109.000000,#f9e84a,1
Crescent City,41.755947,-124.201747,108.000000,#f9e84a,1
Malibu,34.005008,-118.810172,108.000000,#f9e84a,1
Patterson,37.4716,-121.129656,107.000000,#f9e84a,1
Maywood,33.986681,-118.185350,105.000000,#f9e84a,1
Suisun City,38.238247,-122.040244,105.000000,#f9e84a,1
Dixon,38.445464,-121.823297,104.000000,#f9e84a,1
Fort Bragg,39.445722,-123.805292,103.000000,#f9e84a,1
Oakdale,37.766594,-120.847153,103.000000,#f9e84a,1
American Canyon,38.174917,-122.260803,100.000000,#f9e84a,1
Lemon Grove,32.742553,-117.031417,97.000000,#f9e84a,1
Carpinteria,34.398883,-119.518456,96.000000,#f9e84a,1
Lemoore,36.300783,-119.782911,96.000000,#f9e84a,1
San Jacinto,33.783908,-116.958636,95.000000,#f9e84a,1
San Marino,34.121397,-118.106458,95.000000,#f9e84a,1
Paramount,33.889461,-118.159792,94.000000,#f9e84a,1
Tulare,36.207728,-119.347339,93.000000,#f9e84a,1
Twentynine Palms,34.135558,-116.054169,92.000000,#f9e84a,1
Shafter,35.500514,-119.271775,91.000000,#f9e84a,1
Norco,33.931125,-117.548661,89.000000,#f9e84a,1
Capitola,36.975228,-121.953292,88.000000,#f9e84a,1
Rio Vista,38.15575,-121.691344,88.000000,#f9e84a,1
Colton,34.073903,-117.313656,86.000000,#f9e84a,1
Brisbane,37.680767,-122.399972,85.000000,#f9e84a,1
Taft,35.142467,-119.456508,85.000000,#f9e84a,1
Imperial Beach,32.583944,-117.113086,84.000000,#f9e84a,1
Kingsburg,36.513839,-119.554017,84.000000,#f9e84a,1
Morro Bay,35.365808,-120.849900,83.000000,#f9e84a,1
Santa Fe Springs,33.947236,-118.085344,83.000000,#f9e84a,1
Rancho Mirage,33.739744,-116.412789,78.000000,#f9e84a,1
Stanton,33.802517,-117.993117,78.000000,#f9e84a,1
Madera,36.961336,-120.060717,77.000000,#f9e84a,1
Los Banos,37.058278,-120.849914,76.000000,#f9e84a,1
Riverbank,37.736039,-120.935489,76.000000,#f9e84a,1
Gridley,39.363778,-121.693583,75.000000,#f9e84a,1
Pismo Beach,35.142753,-120.641283,74.000000,#f9e84a,1
Santa Paula,34.354167,-119.059269,74.000000,#f9e84a,1
Cotati,38.327778,-122.709167,73.000000,#f9e84a,1
Port Hueneme,34.180728,-119.208158,73.000000,#f9e84a,1
Selma,36.570783,-119.612075,73.000000,#f9e84a,1
Banning,33.925572,-116.876411,71.000000,#f9e84a,1
King City,36.212744,-121.126028,71.000000,#f9e84a,1
El Centro,32.792,-115.563050,69.000000,#f9e84a,1
Lakeport,39.04295,-122.915828,69.000000,#f9e84a,1
Willits,39.409608,-123.355567,68.000000,#f9e84a,1
Barstow,34.895797,-117.017283,67.000000,#f9e84a,1
Marysville,39.145725,-121.591356,67.000000,#f9e84a,1
Orland,39.747381,-122.196375,66.000000,#f9e84a,1
Grand Terrace,34.033903,-117.313653,63.000000,#f9e84a,1
Montclair,34.077511,-117.689778,63.000000,#f9e84a,1
Villa Park,33.814461,-117.813111,63.000000,#f9e84a,1
Artesia,33.865847,-118.083122,62.000000,#f9e84a,1
Desert Hot Springs,33.961125,-116.501678,61.000000,#f9e84a,1
Fortuna,40.598186,-124.157275,61.000000,#f9e84a,1
Grover Beach,35.121642,-120.621283,61.000000,#f9e84a,1
Loma Linda,34.048347,-117.261153,59.000000,#f9e84a,1
Dinuba,36.543283,-119.387067,58.000000,#f9e84a,1
South El Monte,34.051956,-118.046733,58.000000,#f9e84a,1
Porterville,36.065231,-119.016767,57.000000,#f9e84a,1
Lathrop,37.822706,-121.276611,56.000000,#f9e84a,1
Coalinga,36.139678,-120.360150,55.000000,#f9e84a,1
Fillmore,34.399164,-118.918153,54.000000,#f9e84a,1
Mount Shasta,41.410806,-122.194575,52.000000,#f9e84a,1
Anderson,40.448208,-122.297783,51.000000,#f9e84a,1
Cloverdale,38.805461,-123.017222,50.000000,#f9e84a,1
Exeter,36.296061,-119.142053,50.000000,#f9e84a,1
Wasco,35.594125,-119.340947,50.000000,#f9e84a,1
Reedley,36.596339,-119.450403,47.000000,#f9e84a,1
Sanger,36.708006,-119.555964,47.000000,#f9e84a,1
Adelanto,34.582769,-117.409214,45.000000,#f9e84a,1
Brawley,32.978658,-115.530267,43.000000,#f9e84a,1
Calimesa,34.003903,-117.061975,42.000000,#f9e84a,1
Hughson,37.602725,-120.866481,42.000000,#f9e84a,1
Imperial,32.847553,-115.569439,41.000000,#f9e84a,1
Soledad,32.991156,-117.271147,41.000000,#f9e84a,1
Weed,41.42265,-122.386128,40.000000,#f9e84a,1
Calexico,32.678947,-115.498883,37.000000,#f9e84a,1
Willows,39.524325,-122.193592,36.000000,#f9e84a,1
Big Bear Lake,34.243897,-116.911422,35.000000,#f9e84a,1
Delano,35.768842,-119.247053,34.000000,#f9e84a,1
Newman,37.313828,-121.020761,34.000000,#f9e84a,1
Colfax,39.100731,-120.953275,33.000000,#f9e84a,1
Escalon,37.797428,-120.996603,33.000000,#f9e84a,1
Jackson,38.348803,-120.774103,32.000000,#f9e84a,1
Bishop,37.363539,-118.395111,31.000000,#f9e84a,1
Coachella,33.6803,-116.173894,31.000000,#f9e84a,1
Holtville,32.811161,-115.380264,31.000000,#f9e84a,1
Indian Wells,33.717631,-116.340756,31.000000,#f9e84a,1
San Juan Bautista,36.845511,-121.537997,31.000000,#f9e84a,1
Arvin,35.2018,-118.833106,30.000000,#f9e84a,1
Kerman,36.723558,-120.059878,30.000000,#f9e84a,1
Colusa,39.214333,-122.009417,27.000000,#f9e84a,1
Greenfield,36.3208,-121.243814,27.000000,#f9e84a,1
Waterford,37.641319,-120.760483,26.000000,#f9e84a,1
Ferndale,40.576242,-124.263944,25.000000,#f9e84a,1
Susanville,40.416283,-120.653006,25.000000,#f9e84a,1
Buellton,34.613597,-120.192650,24.000000,#f9e84a,1
Calistoga,38.578797,-122.579706,24.000000,#f9e84a,1
Clearlake,38.958231,-122.626372,24.000000,#f9e84a,1
Shasta Lake,40.680428,-122.370842,24.000000,#f9e84a,1
Yreka,41.735419,-122.634472,23.000000,#f9e84a,1
Biggs,39.412389,-121.712750,22.000000,#f9e84a,1
Chowchilla,37.123,-120.260175,22.000000,#f9e84a,1
Live Oak,36.983561,-121.980517,22.000000,#f9e84a,1
McFarland,35.678011,-119.229275,22.000000,#f9e84a,1
Fowler,36.630506,-119.678469,21.000000,#f9e84a,1
Gonzales,36.506628,-121.444381,21.000000,#f9e84a,1
Solvang,34.595819,-120.137647,21.000000,#f9e84a,1
Angels Camp,38.067783,-120.538531,20.000000,#f9e84a,1
Gustine,37.257717,-120.998814,20.000000,#f9e84a,1
Sutter Creek,38.392967,-120.802436,20.000000,#f9e84a,1
Wheatland,39.009894,-121.423014,20.000000,#f9e84a,1
Hawaiian Gardens,33.831403,-118.072842,19.000000,#f9e84a,1
Lindsay,36.203006,-119.088161,19.000000,#f9e84a,1
Livingston,37.386883,-120.723533,19.000000,#f9e84a,1
California City,35.1258,-117.985903,18.000000,#f9e84a,1
Corning,39.927658,-122.179156,18.000000,#f9e84a,1
Trinidad,41.059292,-124.143125,18.000000,#f9e84a,1
Ione,38.352692,-120.932717,17.000000,#f9e84a,1
Dunsmuir,41.208208,-122.271953,16.000000,#f9e84a,1
Tulelake,41.955989,-121.477492,15.000000,#f9e84a,1
Firebaugh,36.858839,-120.456008,13.000000,#f9e84a,1
Woodlake,36.413561,-119.098717,13.000000,#f9e84a,1
Blue Lake,40.882908,-123.983950,12.000000,#f9e84a,1
Blythe,33.617233,-114.589175,12.000000,#f9e84a,1
Avalon,33.342819,-118.328228,11.000000,#f9e84a,1
Montague,41.728197,-122.527800,11.000000,#f9e84a,1
Williams,39.154614,-122.149419,11.000000,#f9e84a,1
Alturas,41.487114,-120.542456,10.000000,#f9e84a,1
Corcoran,37.977978,-122.031072,9.000000,#f9e84a,1
Isleton,38.161861,-121.611622,9.000000,#f9e84a,1
Piedmont,37.824372,-122.231636,9.000000,#f9e84a,1
Rio Dell,40.4993,-124.106436,9.000000,#f9e84a,1
Huron,36.202731,-120.102917,8.000000,#f9e84a,1
Point Arena,38.908797,-123.693072,8.000000,#f9e84a,1
Dorris,41.967369,-121.918061,7.000000,#f9e84a,1
Dos Palos,36.986058,-120.626572,7.000000,#f9e84a,1
Etna,41.456806,-122.894756,6.000000,#f9e84a,1
Guadalupe,34.971644,-120.571836,6.000000,#f9e84a,1
Needles,34.848061,-114.614133,6.000000,#f9e84a,1
Plymouth,38.481853,-120.844658,5.000000,#f9e84a,1
Avenal,36.004122,-120.129028,4.000000,#f9e84a,1
Fort Jones,41.663864,-124.252892,4.000000,#f9e84a,1
Portola,39.810458,-120.469103,4.000000,#f9e84a,1
Calipatria,33.125597,-115.514153,3.000000,#f9e84a,1
Farmersville,36.297728,-119.206778,3.000000,#f9e84a,1
Loyalton,39.676294,-120.241039,3.000000,#f9e84a,1
Maricopa,35.058858,-119.400950,2.000000,#f9e84a,1
Parlier,36.611617,-119.527072,2.000000,#f9e84a,1
Bell Gardens,33.965292,-118.151458,1.000000,#f9e84a,1
Orange Cove,36.624394,-119.313731,1.000000,#f9e84a,1
San Joaquin,36.606617,-120.189044,1.000000,#f9e84a,1
Westmorland,33.037267,-115.621383,1.000000,#f9e84a,1""")



cities = pd.read_csv(calcit)
cities = cities.dropna()

# map_osm = folium.Map(location=[36.611617,-119.527072], zoom_start=5)

# for i, row in cities.iterrows():
#     folium.CircleMarker([row['Latitude'], row['Longitude']],
#                         radius=row['Size'],
#                         color=row['Color'],
#                         fill_color=row['Color'],
#                        ).add_to(map_osm)



map_osm2 = folium.Map([36.611617,-119.527072], zoom_start=6,tiles='cartodbdark_matter')
ziparr = []
for i, row in cities.iterrows():
    ziparr.append([row['Latitude'],row['Longitude'], float(row['Total Donors'].replace(",",""))])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
map_osm2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ## Ubicaciones clave donde la densidad de donantes es mayor
#
# Las principales ciudades con mayor concentración de donantes son:
#
# - Los Ángeles: 17,922
# - San Francisco: 16,553
# - San Diego: 9,072
# - San José: 7,674
# - Oakland: 6,783
#
# ---
#
# ## 2.4.2 Ubicación de los donantes en Florida

# %%
c = pd.read_csv('zip_codes_states.csv')
c = c.dropna()

fldf = c[c['state'] == 'FL'][['city', 'latitude', 'longitude']]

fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
t = donors_df[donors_df['Donor State'] == 'Florida']['Donor City'].value_counts()
fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([29.813456, -82.472049], zoom_start=6.2,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# > La región de los tres condados de Florida: Palm Beach, Miami-Dade y Broward, presenta una alta concentración de donantes. La ciudad capital: Tampa, también cuenta con un número significativo de donantes. Algunos donantes también se ubican en una de las zonas más costosas y en el extremo más al sur de los Estados Unidos, conocida como el área de Key West en Florida. A continuación, se muestran los recuentos y cantidades respectivas de donantes de las 5 ciudades principales:
#
# > Miami (9309), Tampa (6016), Orlando (5658), Jacksonville (4598), Fort Lauderdale (4311), West Palm Beach (2400)
#
# ## <a id="2.4.3">2.4.3 Dónde se ubican los donantes en Nueva York</a>

# %%
fldf = c[c['state'] == 'NY'][['city', 'latitude', 'longitude']]
fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
fldf
t = donors_df[donors_df['Donor State'] == 'New York']['Donor City'].value_counts()

fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([42.315975, -74.065515], zoom_start=6.2,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# > Los donantes de Nueva York provienen principalmente de la ciudad de Nueva York. Las 5 ciudades principales son:
# - Nueva York                26820
# - Brooklyn                  21715
# - Staten Island              4516
# - Bronx                      4455
# - Buffalo                    2232
#
# ## <a id="2.4.4">2.4.4 Dónde se ubican los donantes en Texas</a>

# %%
fldf = c[c['state'] == 'TX'][['city', 'latitude', 'longitude']]
fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
fldf
t = donors_df[donors_df['Donor State'] == 'Texas']['Donor City'].value_counts()

fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([31.884540, -97.077218], zoom_start=6.2,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# > Las principales ciudades de Texas donde se ubican los donantes son:
#
# - Houston             15404
# - Austin               9958
# - Dallas               7818
# - San Antonio          6465
# - Fort Worth           4350
#
# ## <a id="2.5">2.5 ¿Dónde se ubican los donantes?</a>

# %%
fldf = c[['city', 'latitude', 'longitude']]
fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
fldf
t = donors_df['Donor City'].value_counts()
fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([39.3714557,-94.3541242], zoom_start=3.5,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# > Aunque el mayor número de donantes proviene del estado de California, ubicado en la costa oeste, la región de la costa este de EE. UU. tiene una alta densidad de donantes en comparación con el oeste. Un número significativo de donantes también se encuentra en Hawái y Alaska.
#
# ## <a id="2.6">2.6 Número de donantes docentes y no docentes de cada estado</a>

# %%
# ¿Qué estado tiene el máximo de donantes maestros?
tempdf = donors_df.groupby(['Donor State', 'Donor Is Teacher']).agg({'Donor Is Teacher' : 'count' }).rename(columns={'Donor Is Teacher' : 'Teacher Donor Counts'}).reset_index()

no_df = tempdf[tempdf['Donor Is Teacher']=='No']
no_x = no_df['Donor State']
no_y = no_df['Teacher Donor Counts']
yes_df = tempdf[tempdf['Donor Is Teacher']=='Yes']
yes_x = yes_df['Donor State']
yes_y = yes_df['Teacher Donor Counts']

trace1 = go.Bar(
    x=no_x,
    y=no_y,
    name='Donantes No Maestros',
    marker=dict(color='#f259d6'),
    opacity=0.8
)
trace2 = go.Bar(
    x=yes_x,
    y=yes_y,
    name='Donantes Maestros',
    marker=dict(color='#f7bb31'),
    opacity=0.8
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    margin=dict(b=120),
    title = 'Estados y distribución de Donantes Maestros y No Maestros',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')

# %% [markdown]
# > El número de donantes docentes es siempre muy reducido en todos los estados. Los registros donde el estado es igual a "others" (otros) presentan la mayor cantidad de donantes docentes, con aproximadamente 28,000.
#
# ## <a id="3"> 3. Exploración de donaciones </a>
#
# El archivo de donaciones incluye información sobre las donaciones realizadas por los donantes, el monto total de la donación, la secuencia del carrito del donante, la fecha, el proyecto y el ID del donante.
#
# ## <a id="3.1"> 3.1 Instantáneas de donaciones </a>

# %%
# Renombrar columnas para mostrar en español
donations_df_es = donations_df.rename(columns={
    'Donation ID': 'ID de Donación',
    'Donation Included Optional Donation': 'Incluyó Donación Opcional',
    'Donation Amount': 'Monto de Donación',
    'Donor Cart Sequence': 'Secuencia de Carrito del Donante',
    'Donation Received Date': 'Fecha de Recepción de Donación',
    'Project ID': 'ID de Proyecto',
    'Donor ID': 'ID de Donante'
})

# Mostrar las primeras 3 filas de donaciones con columnas en español
donations_df_es[['ID de Donación', 'Incluyó Donación Opcional', 'Monto de Donación',
       'Secuencia de Carrito del Donante', 'Fecha de Recepción de Donación', 'ID de Proyecto', 'ID de Donante']].head(3)

# donations_df_es.columns  # Ver todas las columnas disponibles (en español)

# len(donations_df_es)  # Total de donaciones en el dataset

# Porcentaje de donaciones mayores a $20,000 USD
# len(donations_df_es[donations_df_es['Monto de Donación'] > 20000]) / len(donations_df_es)

# Porcentaje de donaciones mayores a $10,000 USD
# len(donations_df_es[donations_df_es['Monto de Donación'] > 10000]) / len(donations_df_es)

# Número de donaciones menores a $1 USD
# len(donations_df_es[donations_df_es['Monto de Donación'] < 1])

# Promedio del monto de donación
# np.mean(donations_df_es['Monto de Donación'])
# Out:
#                      ID de Donación Incluyó Donación Opcional  \
# 0  ec672f25610ef68872f89e415071a106                       Yes
# 1  3722d51b9086c4a259b81863e476175c                       Yes
# 2  defa7e1e3648434b32b58d9e715de26f                        No
#
#    Monto de Donación  Secuencia de Carrito del Donante  \
# 0               20.0                                 6
# 1               20.0                                 3
# 2               40.0                                 8
#
#   Fecha de Recepción de Donación                    ID de Proyecto  \
# 0            2015-03-17 13:38:42  98b77eee98e664fa9e4c13dece1ece79
# 1            2018-03-31 23:26:23  59e1daff6074d4ad15c7ede3865e57ed
# 2            2016-11-27 08:41:35  662f19dda359daf06a06238efb88df26
#
#                       ID de Donante
# 0  8eb867c603bef104a733901a7415a3b4
# 1  99bf9e7fd1765b1e541a327d71c66bb6
# 2  5995a40bd1cb2389cf10e4109935cdf7

# %% [markdown]
# Ha habido un total de **4,687,884 donaciones** hasta abril de 2018 en DonorsChoose. El monto más alto donado es de **60,000 USD**, realizado en 2013. Solo **6 donaciones son mayores a 20,000 USD**, mientras que solo **61 pagos son mayores a 10,000 USD**. La mayoría de los pagos (aproximadamente el **83%** de todas las donaciones) son **menores a 100 USD**. Hay 350 pagos que son menores a 1 USD -> una cantidad pequeña, pero que aun así puede hacer la diferencia. Hasta abril de 2018, DonorsChoose ha recaudado una cantidad total colosal de **284,408,243 USD** a través de su plataforma. El monto promedio de donación en DonorsChoose es de 60 USD. Veamos los detalles de los donantes y proyectos relacionados con estas donaciones en las siguientes secciones.
#
# ## <a id="3.2"> 3.2 Proyectos y sus donaciones </a>
#
# Identifiquemos los proyectos principales y los valores de sus atributos relacionados:
#
# - 3.2.1 Proyectos con el mayor número de donantes
# - 3.2.2 Proyectos con los mayores montos totales financiados
# - 3.2.3 Proyectos con los mayores montos promedio por donante
# - 3.2.4 Proyectos con el mayor monto único donado

# %%
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import iplot

# Calcular estadísticas por proyecto
tempdf = donations_df.groupby('Project ID').agg({
    'Project ID': 'count', 
    'Donation Amount': 'sum'
}).rename(columns={
    'Project ID': "Total Donations", 
    'Donation Amount': "Total Amount"
}).reset_index()

tempdf['Average Donation Amount'] = tempdf['Total Amount'] / tempdf['Total Donations']

# Top 5 proyectos por número de donaciones
tempdf1 = tempdf.sort_values(by=['Total Donations'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pa"+str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Total Donations']
tr1 = go.Bar(x=x, y=y, marker=dict(color='#43ef4b'))

# Top 5 proyectos por monto total
tempdf1 = tempdf.sort_values(by=['Total Amount'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pb"+str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Total Amount']
tr2 = go.Bar(x=x, y=y, marker=dict(color='#7fef84'))

# Top 5 proyectos por promedio (con mínimo 10 donaciones)
tempdf1 = tempdf.sort_values(by=['Average Donation Amount'], ascending=[False])
x = tempdf1[tempdf1['Total Donations'] > 10].head(5)['Project ID']
x = ["Pc"+str(i+1) for i in range(len(x))]
y = tempdf1[tempdf1['Total Donations'] > 10].head(5)['Average Donation Amount']
tr3 = go.Bar(x=x, y=y, marker=dict(color='#a5d1a7'))

# Top 5 proyectos por donación máxima
tempdf = donations_df.groupby('Project ID').agg({
    'Project ID': 'count', 
    'Donation Amount': 'max'
}).rename(columns={
    'Project ID': "Total Donations", 
    'Donation Amount': "Maximum Donations"
}).reset_index()

tempdf1 = tempdf.sort_values(by=['Maximum Donations'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pd"+str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Maximum Donations']
tr4 = go.Bar(x=x, y=y, marker=dict(color='#c0d1c1'))

# Crear subplots con títulos en español
fig = tools.make_subplots(
    rows=2, 
    cols=2, 
    print_grid=False, 
    subplot_titles=[
        'Número de Donaciones',
        'Monto Total Donado',
        'Promedio por Donante (Mín 10 Donaciones)',
        'Monto Máximo de una Donación'
    ]
)

fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 2)
fig.append_trace(tr3, 2, 1)
fig.append_trace(tr4, 2, 2)

# Actualizar layout con título en español
fig['layout'].update(
    height=600, 
    showlegend=False, 
    title='Proyectos Principales - Total Donaciones, Monto Total, Promedio por Donante, Monto Máximo'
)

iplot(fig)

# %% [markdown]
# > - **Principales proyectos**
# > - En la historia de DonorsChoose, diferentes proyectos recibieron un número variable de donaciones, que van desde tan solo 1 hasta un máximo de 800. El número máximo de donaciones realizadas en un solo proyecto es igual a 863. Este fue un proyecto liderado por un maestro y su título fue "**Vallecito StandUpKids Pilot Standing School!**" (como se muestra como Pa1 en el primer gráfico). Se financió un monto total de **108,248.30 USD** en este proyecto y fue financiado en su totalidad el 26 de agosto de 2015.
# > - Hay otros tres proyectos con un número muy grande de donaciones (mayor a 600)
# > - En noviembre de 2016, se inició un proyecto titulado "**Varsity and After-School Fencing Teams in NYC**" (como se muestra como Pc1 en el segundo gráfico) y hubo un total de 18 donaciones. Este proyecto tuvo el mayor monto promedio por donante igual a **1,850 USD**
# > - En el proyecto titulado "**Learning to Play While Playing to Learn!**" (como se muestra como Pd1 en el cuarto gráfico), se realizó la donación única máxima igual a **60,000 USD**, la cual es la mayor cantidad de donación única en la historia de DonorsChoose.
#
# ## <a id="3.3"> 3.3 ¿Quiénes son los principales donantes? </a>
#
# Identifiquemos a los donantes que realizaron algunas de las principales contribuciones y sus valores. Es decir:
# - 3.3.1 Donantes que han realizado el mayor número de donaciones
# - 3.3.2 Donantes que han financiado los mayores montos totales
# - 3.3.3 Donantes que financian los mayores montos promedio en donaciones únicas
# - 3.3.4 Donantes que han financiado el mayor monto único donado

# %%
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import iplot

# Calcular estadísticas por donante
tempdf = donations_df.groupby('Donor ID').agg({
    'Donor ID': 'count', 
    'Donation Amount': 'sum'
}).rename(columns={
    'Donor ID': "Total Donations", 
    'Donation Amount': "Total Amount"
}).reset_index()

tempdf['Average Donation Amount'] = tempdf['Total Amount'] / tempdf['Total Donations']

# Top 5 donantes por número de donaciones
tempdf1 = tempdf.sort_values(by=['Total Donations'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D"+str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Total Donations']
tr1 = go.Bar(x=x, y=y, marker=dict(color='#d141ea'))

# Top 5 donantes por monto total
tempdf1 = tempdf.sort_values(by=['Total Amount'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D"+str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Total Amount']
tr2 = go.Bar(x=x, y=y, marker=dict(color='#db85ea'))

# Top 5 donantes por promedio de donación
tempdf1 = tempdf.sort_values(by=['Average Donation Amount'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D"+str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Average Donation Amount']
tr3 = go.Bar(x=x, y=y, marker=dict(color='#d5b1db'))

# Top 5 donantes por donación máxima
tempdf = donations_df.groupby('Donor ID').agg({
    'Donor ID': 'count', 
    'Donation Amount': 'max'
}).rename(columns={
    'Donor ID': "Total Donations", 
    'Donation Amount': "Maximum Donations"
}).reset_index()

tempdf1 = tempdf.sort_values(by=['Maximum Donations'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D"+str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Maximum Donations']
tr4 = go.Bar(x=x, y=y, marker=dict(color='#ccbece'))

# Crear subplots con títulos en español
fig = tools.make_subplots(
    rows=2, 
    cols=2, 
    print_grid=False, 
    subplot_titles=[
        'Número de Donaciones',
        'Monto Total Donado',
        'Promedio de Donación',
        'Monto Máximo Donado'
    ]
)

fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 2)
fig.append_trace(tr3, 2, 1)
fig.append_trace(tr4, 2, 2)

# Actualizar layout con título en español
fig['layout'].update(
    height=600, 
    showlegend=False, 
    title='Principales Donantes y sus Contribuciones'
)

iplot(fig)

# %% [markdown]
# > - **Donantes más generosos:**
# > - Un donante no docente de **Manhattan Beach, California** ha donado más de **18,000 veces** (mostrado como D1 en el gráfico de la esquina superior izquierda) en DonorsChoose. Otro donante no docente de Nueva York ha donado una cantidad total masiva de **1.8 M USD** en aproximadamente 10,513 donaciones (mostrado como D1 en el gráfico de la esquina superior derecha).
# > - El pago único más alto de **60K** para el proyecto "Learning to Play while Playing to Learn" fue realizado por un donante de **Anahola, Hawái**, quien hasta el momento ha realizado un total de 223 donaciones.
#
# ## <a id="3.4"> 3.4 ¿Qué montos de donación se recibieron y en qué momentos? </a>
#
# ### Donaciones por año
#  - 3.4.1 Número de donaciones por año
#  - 3.4.2 Montos promedio de donación por año

# %%
from plotly.subplots import make_subplots
import plotly.graph_objs as go
from plotly.offline import iplot

# Convertir la fecha de donación
donations_df['Donation Date'] = pd.to_datetime(donations_df['Donation Received Date'])
donations_df['Donation Year'] = donations_df['Donation Date'].dt.year
donations_df['Donation Month'] = donations_df['Donation Date'].dt.month
donations_df['Donation Day'] = donations_df['Donation Date'].dt.day
donations_df['Donation Weekday'] = donations_df['Donation Date'].dt.weekday
donations_df['Donation Hour'] = donations_df['Donation Date'].dt.hour

# Resumen por año
t1 = donations_df.groupby(['Donation Year']).agg({
    'Donation Month': 'count',
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Month': 'Total Donations',
    'Donation Amount': 'Average Amount'
})

x = t1['Donation Year']
y1 = t1['Total Donations']
y2 = t1['Average Amount']

trace1 = go.Scatter(
    x=x[:-1],
    y=y1[:-1],
    fill='tozeroy',
    fillcolor='#fcc45f',
    mode='none'
)

trace2 = go.Scatter(
    x=x[:-1],
    y=y2[:-1],
    fill='tozeroy',
    fillcolor='#e993f9',
    mode='none'
)

fig = make_subplots(
    rows=1,
    cols=2,
    subplot_titles=(
        "<b>Donaciones por Año</b>",
        "<b>Monto Promedio de Donación por Año</b>"
    )
)

fig.add_trace(trace1, row=1, col=1)
fig.add_trace(trace2, row=1, col=2)

fig.update_layout(
    height=300,
    showlegend=False
)

fig.update_yaxes(
    showgrid=False,
    zeroline=False,
    showline=False,
    ticks='',
    showticklabels=False,
    row=1,
    col=1
)

fig.update_yaxes(
    showgrid=False,
    zeroline=False,
    showline=False,
    ticks='',
    showticklabels=False,
    row=1,
    col=2
)

iplot(fig)

# %% [markdown]
# > - Desde el año **2012**, el número de donaciones en DonorsChoose ha aumentado de manera regular. Con aproximadamente **150 donaciones** recibidas en 2012, DonorsChoose recibió cerca de **1.1 Millón de donaciones** en el año **2017**.
# > - El monto más alto recibido en 2017 fue de **USD 31,856**, el cual fue recibido de un donante de **Lafayette, Colorado**. Esta donación fue recibida el **2 de marzo de 2017**.
# > - En el mismo año, un número gigantesco de donaciones fue recibido de un donante de **Manhattan Beach, California**, quien realizó **13,751 donaciones**.
# > - El monto promedio de donación recibido por año es cercano a **USD 60**, mientras que fue más alto en el año inicial, es decir, **2012**, igual a **USD 166**.
#
# ### Donaciones por Mes
#
# - *3.4.3* Número de Donaciones por Mes
# - *3.4.4* Promedio de Donaciones por Mes

# %%
from plotly.subplots import make_subplots
import plotly.graph_objs as go
from plotly.offline import iplot

# Resumen de donaciones por mes
t2 = donations_df.groupby(['Donation Month']).agg({
    'Donation Year': 'count',
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Year': 'Total Donations',
    'Donation Amount': 'Average Amount'
})

x = t2['Donation Month']
y1 = t2['Total Donations']
y2 = t2['Average Amount']

# Gráfica del número de donaciones
trace1 = go.Scatter(
    x=x,
    y=y1,
    fill='tozeroy',
    fillcolor='#fcc45f',
    mode='none'
)

# Gráfica del monto promedio de donación
trace2 = go.Scatter(
    x=x,
    y=y2,
    fill='tozeroy',
    fillcolor='#e993f9',
    mode='none'
)

# Crear subgráficas
fig = make_subplots(
    rows=1,
    cols=2,
    subplot_titles=(
        "<b>Donaciones por Mes</b>",
        "<b>Monto Promedio de Donación por Mes</b>"
    )
)

fig.add_trace(trace1, row=1, col=1)
fig.add_trace(trace2, row=1, col=2)

# Configuración del diseño
fig.update_layout(
    height=300,
    showlegend=False
)

# Configuración del eje Y de la primera gráfica
fig.update_yaxes(
    showgrid=False,
    zeroline=False,
    showline=False,
    ticks='',
    showticklabels=False,
    row=1,
    col=1
)

# Configuración del eje Y de la segunda gráfica
fig.update_yaxes(
    showgrid=False,
    zeroline=False,
    showline=False,
    ticks='',
    showticklabels=False,
    row=1,
    col=2
)

iplot(fig)

# %% [markdown]
# > - El mayor número de donaciones se recibe en el mes de **Agosto** con **577,274 donaciones**, seguido por el mes de **Septiembre** con **518,908 donaciones**.
# > - El menor número de donaciones se recibe en el mes de **Junio** con **191,221 donaciones** y el mes de **Mayo** con **243,440 donaciones**, probablemente debido a las vacaciones de verano.
# > - El monto promedio de donación más alto se recibe en el mes de **Diciembre** con **USD 80**, mientras que el más bajo es en el mes de **Julio** con **USD 51**.
# > - En promedio, el monto promedio de donación por año es cercano a **USD 59**.
#
# ### Donaciones por Día del Mes
#
# - *3.4.5* Número de Donaciones por Día del Mes
# - *3.4.6* Promedio de Donaciones por Día del Mes

# %%
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import iplot

# Agrupar donaciones por día del mes
t3 = donations_df.groupby(['Donation Day']).agg({
    'Donation Year': 'count', 
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Year': 'Total Donations', 
    'Donation Amount': 'Average Amount'
})

x = t3['Donation Day']
y1 = t3['Total Donations']
y2 = t3['Average Amount']

trace1 = go.Scatter(
    x=x, 
    y=y1, 
    fill='tozeroy', 
    fillcolor='#fcc45f', 
    mode='none'
)
trace2 = go.Scatter(
    x=x, 
    y=y2, 
    fill='tozeroy', 
    fillcolor="#e993f9", 
    mode='none'
)

fig = tools.make_subplots(
    rows=1, 
    cols=2, 
    print_grid=False, 
    subplot_titles=[
        "<b>Donaciones por Día del Mes</b>", 
        "<b>Promedio de Donación por Día del Mes</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

# CORREGIDO: Eliminar autotick y usar propiedades válidas
fig['layout'].update(
    height=300, 
    showlegend=False, 
    yaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
        ticks=''
    ), 
    yaxis2=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
        ticks=''
    )
)

iplot(fig)

# %% [markdown]
# ### Donaciones por Día de la Semana
#
# - *3.4.7* Número de Donaciones por Día de la Semana
# - *3.4.8* Promedio de Donaciones por Día de la Semana

# %%
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import iplot

# Agrupar donaciones por día de la semana
t4 = donations_df.groupby(['Donation Weekday']).agg({
    'Donation Year': 'count', 
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Year': 'Total Donations', 
    'Donation Amount': 'Average Amount'
})

x = t4['Donation Weekday']
y1 = t4['Total Donations']
y2 = t4['Average Amount']

trace1 = go.Scatter(
    x=x, 
    y=y1, 
    fill='tozeroy', 
    fillcolor='#fcc45f', 
    mode='none'
)
trace2 = go.Scatter(
    x=x, 
    y=y2, 
    fill='tozeroy', 
    fillcolor="#e993f9", 
    mode='none'
)

fig = tools.make_subplots(
    rows=1, 
    cols=2, 
    print_grid=False, 
    subplot_titles=[
        "<b>Donaciones por Día de la Semana</b>", 
        "<b>Promedio de Donación por Día de la Semana</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

# CORREGIDO: Eliminar autotick y usar propiedades válidas
fig['layout'].update(
    height=300, 
    showlegend=False, 
    yaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
        ticks=''
    ), 
    yaxis2=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
        ticks=''
    )
)

iplot(fig)

# %% [markdown]
# > - El número de donaciones es más alto en los primeros días de la semana, es decir, **Lunes**, **Martes** y **Miércoles**, con **700K**, **800K** y **750K** donaciones totales respectivamente.
# > - La cantidad disminuye con los siguientes días de la semana.
# > - El menor número de donaciones se recibe los **sábados**, como se observa en la gráfica.
#
# ### Donaciones por Hora
#
# - *3.4.9* Número de Donaciones por Hora
# - *3.4.10* Promedio de Donaciones por Hora

# %%
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import iplot

# Agrupar donaciones por hora
t5 = donations_df.groupby(['Donation Hour']).agg({
    'Donation Month': 'count', 
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Month': 'Total Donations', 
    'Donation Amount': 'Average Amount'
})

x = t5['Donation Hour']
y1 = t5['Total Donations']
y2 = t5['Average Amount']

trace1 = go.Scatter(
    x=x[:-1], 
    y=y1[:-1], 
    fill='tozeroy', 
    fillcolor='#fcc45f', 
    mode='none'
)
trace2 = go.Scatter(
    x=x[:-1], 
    y=y2[:-1], 
    fill='tozeroy', 
    fillcolor="#e993f9", 
    mode='none'
)

fig = tools.make_subplots(
    rows=1, 
    cols=2, 
    print_grid=False, 
    subplot_titles=[
        "<b>Donaciones por Hora</b>", 
        "<b>Promedio de Donación por Hora</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

# CORREGIDO: Eliminar autotick y usar propiedades válidas
fig['layout'].update(
    height=300, 
    showlegend=False, 
    yaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
        ticks=''
    ), 
    yaxis2=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
        ticks=''
    )
)

iplot(fig)

# %% [markdown]
# ## <a id="3.5">3.5 Donaciones Opcionales y Donantes Docentes</a>
#
# ### <a id="3.5.1">3.5.1 Total de Donaciones Opcionales y su Monto Promedio</a>

# %%
# Donaciones opcionales
tempdf = donations_df.groupby('Donation Included Optional Donation').agg({
    'Donation Included Optional Donation': 'count',
    'Donation Amount': 'mean'
})

values1 = list(tempdf['Donation Included Optional Donation'])
values2 = list(tempdf['Donation Amount'])
values2t = ["$" + str(int(x)) for x in values2]

labels = list(tempdf.index)

# Traducir etiquetas
mp = {
    'Yes': 'Con donación opcional',
    'No': 'Sin donación opcional'
}
labels = [mp[x] for x in labels]

trace1 = go.Pie(
    labels=labels,
    values=values1,
    marker=dict(colors=['#75e575', '#ea7c96'])
)

trace2 = go.Pie(
    labels=labels,
    values=values2,
    marker=dict(colors=['#75e575', '#ea7c96']),
    textinfo="text",
    text=values2t
)

fig = {
    "data": [
        {
            "values": values1,
            "labels": list(reversed(labels)),
            "domain": {"x": [0, .48]},
            "marker": dict(colors=['#f9345b', '#75e575']),
            "name": "Número de donaciones con donación opcional",
            "type": "pie"
        },
        {
            "values": values2,
            "labels": labels,
            "marker": dict(colors=['#75e575', '#f9345b']),
            "domain": {"x": [.52, 1]},
            "name": "Monto promedio de las donaciones opcionales",
            "text": values2t,
            "textinfo": "text",
            "type": "pie"
        }
    ],
    "layout": {
        "title": "Donaciones Opcionales: Cantidad Total y Monto Promedio de Donación"
    }
}

iplot(fig)

# %% [markdown]
# > - **Donaciones opcionales:**
# > - Los proyectos de **DonorsChoose** ofrecen la posibilidad de realizar una **donación opcional** para apoyar el funcionamiento de la plataforma.
# > - El **monto promedio** de las donaciones que incluyen una contribución opcional es de aproximadamente **USD 58**, mientras que el promedio de las donaciones sin contribución opcional es de **USD 73**.
# > - Del total de las donaciones realizadas, alrededor del **15 %** incluyeron una **donación opcional**.
#
# ### <a id="3.5.2">3.5.2 Total de Donaciones de Donantes Docentes y su Monto Promedio</a>

# %%
# Combinar los conjuntos de datos de donantes y donaciones
combined_df = donations_df.merge(donors_df, on='Donor ID', how='inner')

# Resumen de donaciones de docentes y no docentes
tempdf = combined_df.groupby('Donor Is Teacher').agg({
    'Donor Is Teacher': 'count',
    'Donation Amount': 'mean'
})

values1 = list(tempdf['Donor Is Teacher'])
values2 = list(tempdf['Donation Amount'])
values2t = ["$" + str(int(x)) for x in values2]

labels = list(tempdf.index)

# Traducir etiquetas
mp = {
    'Yes': 'Donante Docente',
    'No': 'Donante No Docente'
}
labels = [mp[x] for x in labels]

trace1 = go.Pie(
    labels=labels,
    values=values1,
    marker=dict(colors=['#ab97db', '#b0b1b2'])
)

trace2 = go.Pie(
    labels=labels,
    values=values2,
    marker=dict(colors=['#ab97db', '#b0b1b2']),
    textinfo="text",
    text=values2t
)

fig = {
    "data": [
        {
            "values": values1,
            "labels": labels,
            "domain": {"x": [0, .48]},
            "marker": dict(colors=['#ab97db', '#b0b1b2']),
            "name": "Número de donaciones de docentes y no docentes",
            "type": "pie"
        },
        {
            "values": values2,
            "labels": labels,
            "domain": {"x": [.52, 1]},
            "marker": dict(colors=['#ab97db', '#b0b1b2']),
            "name": "Monto promedio de las donaciones",
            "text": values2t,
            "textinfo": "text",
            "type": "pie"
        }
    ],
    "layout": {
        "title": "Donantes Docentes y No Docentes: Cantidad Total y Monto Promedio de Donación"
    }
}

iplot(fig)

# %% [markdown]
# > - **Donantes docentes:**
# > - Aproximadamente el **29 %** del total de las donaciones en **DonorsChoose** son realizadas por **donantes que también son docentes**. La mayor concentración de estos donantes se encuentra en el estado de **California**.
# > - El **monto promedio de las donaciones** realizadas por docentes es de aproximadamente **USD 45**, mientras que el promedio de las donaciones realizadas por personas que no son docentes es de **USD 66**.

# %%
def mapp(df, scl, t):

    state_to_code = {
        'District of Columbia': 'DC',
        'Mississippi': 'MS',
        'Oklahoma': 'OK',
        'Delaware': 'DE',
        'Minnesota': 'MN',
        'Illinois': 'IL',
        'Arkansas': 'AR',
        'New Mexico': 'NM',
        'Indiana': 'IN',
        'Maryland': 'MD',
        'Louisiana': 'LA',
        'Idaho': 'ID',
        'Wyoming': 'WY',
        'Tennessee': 'TN',
        'Arizona': 'AZ',
        'Iowa': 'IA',
        'Michigan': 'MI',
        'Kansas': 'KS',
        'Utah': 'UT',
        'Virginia': 'VA',
        'Oregon': 'OR',
        'Connecticut': 'CT',
        'Montana': 'MT',
        'California': 'CA',
        'Massachusetts': 'MA',
        'West Virginia': 'WV',
        'South Carolina': 'SC',
        'New Hampshire': 'NH',
        'Wisconsin': 'WI',
        'Vermont': 'VT',
        'Georgia': 'GA',
        'North Dakota': 'ND',
        'Pennsylvania': 'PA',
        'Florida': 'FL',
        'Alaska': 'AK',
        'Kentucky': 'KY',
        'Hawaii': 'HI',
        'Nebraska': 'NE',
        'Missouri': 'MO',
        'Ohio': 'OH',
        'Alabama': 'AL',
        'Rhode Island': 'RI',
        'South Dakota': 'SD',
        'Colorado': 'CO',
        'New Jersey': 'NJ',
        'Washington': 'WA',
        'North Carolina': 'NC',
        'New York': 'NY',
        'Texas': 'TX',
        'Nevada': 'NV',
        'Maine': 'ME'
    }

    # Agregar el código de cada estado
    df['state_code'] = df['state'].apply(
        lambda x: state_to_code.get(x, "")
    )

    data = [
        dict(
            type='choropleth',
            colorscale=scl,
            autocolorscale=False,
            locations=df['state_code'],
            z=df['counts'],
            locationmode='USA-states',
            text=df['state'],
            marker=dict(
                line=dict(
                    color='rgb(255,255,255)',
                    width=2
                )
            ),
            colorbar=dict(
                title='Donantes'
            )
        )
    ]

    layout = dict(
        title=t,
        geo=dict(
            scope='usa',
            projection=dict(type='albers usa'),
            showlakes=True,
            lakecolor='rgb(255,255,255)'
        )
    )

    fig = dict(data=data, layout=layout)
    iplot(fig)

# %% [markdown]
# ## <a id="3.6">3.6 ¿Qué estados recibieron las donaciones individuales más altas?</a>
#
# - 3.6.1 Estados con los montos de donación más altos
# - 3.6.2 Ciudades con los montos de donación más altos

# %%
from plotly.subplots import make_subplots

# Montos máximos de donación por estado
tempdf = combined_df.groupby(['Donor State']).agg({
    'Donation Amount': 'max'
}).reset_index()

t1 = tempdf.sort_values('Donation Amount', ascending=False)

# Montos máximos de donación por ciudad
tempdf = combined_df.groupby(['Donor City']).agg({
    'Donation Amount': 'max'
}).reset_index()

t2 = tempdf.sort_values('Donation Amount', ascending=False)

# DataFrame para estados
statesdf = pd.DataFrame()
statesdf['state'] = t1['Donor State']
statesdf['counts'] = t1['Donation Amount']

# DataFrame para ciudades
citydf = pd.DataFrame()
citydf['state'] = t2['Donor City']
citydf['counts'] = t2['Donation Amount']

# Escala de colores
scl = [
    [0.0, 'rgb(240,240,240)'],
    [0.2, 'rgb(220,220,220)'],
    [0.4, 'rgb(180,180,180)'],
    [0.6, 'rgb(154,154,154)'],
    [0.8, 'rgb(117,117,117)'],
    [1.0, 'rgb(84,84,84)']
]

# Mapa de los estados
mapp(statesdf, scl, 'Montos Máximos de Donación Individual por Estado')

# Gráficas de barras
trace1 = bar_hor_noagg(
    list(reversed(list(statesdf['state'][:10]))),
    list(reversed(list(statesdf['counts'][:10]))),
    "Top 10 Estados con la Donación Individual Más Alta",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)

trace2 = bar_hor_noagg(
    list(reversed(list(citydf['state'][:10]))),
    list(reversed(list(citydf['counts'][:10]))),
    "Top 10 Ciudades con la Donación Individual Más Alta",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)

# Crear subgráficas
fig = make_subplots(
    rows=1,
    cols=2,
    subplot_titles=(
        'Estados con la Donación Individual Más Alta',
        'Ciudades con la Donación Individual Más Alta'
    )
)

fig.add_trace(trace1, row=1, col=1)
fig.add_trace(trace2, row=1, col=2)

fig.update_layout(
    height=400,
    showlegend=False
)

iplot(fig)

# %% [markdown]
# > - **Donaciones individuales más altas por ubicación:**
# > - Aunque **Hawái** y **Colorado** registran un menor número de donaciones en comparación con otros estados, son los que han recibido las **donaciones individuales de mayor monto**.
# > - Las ciudades de **Anahola**, **Lafayette** y **Palo Alto** destacan por haber recibido las contribuciones individuales más altas, con aproximadamente **USD 60 mil**, **USD 31 mil** y **USD 26 mil**, respectivamente.
#
# ## <a id="3.7">3.7 ¿Qué estado recibe el mayor monto promedio de donaciones?</a>

# %%
# Montos Promedio de Donación
tempdf = combined_df.groupby(['Donor State']).agg({'Donation Amount':'mean'}).reset_index()
t1 = tempdf.sort_values('Donation Amount', ascending=False)

tempdf = combined_df.groupby(['Donor City']).agg({'Donation Amount':'mean'}).reset_index()
t2 = tempdf.sort_values('Donation Amount', ascending=False)

statesdf = pd.DataFrame()
statesdf['state'] = t1['Donor State']
statesdf['counts'] = t1['Donation Amount']
statesdf

citydf = pd.DataFrame()
citydf['state'] = t2['Donor City']
citydf['counts'] = t2['Donation Amount']
citydf

scl = [[0.0, 'rgb(248,255,206)'],[0.2, 'rgb(203,255,205)'],[0.4, 'rgb(155,255,164)'], [0.6, 'rgb(79,255,178)'],[0.8, 'rgb(15,183,132)'], [1, '#008059']]
# scl = [[0.0, 'rgb(240,240,240)'],[0.2, 'rgb(220,220,220)'],[0.4, 'rgb(180,180,180)'], [0.6, 'rgb(154,154,154)'],[0.8, 'rgb(117,117,117)'],[1.0, 'rgb(84,84,84)']]
mapp(statesdf, scl, 'Promedio de Montos de Donación por Estado')

trace1 = bar_hor_noagg(list(reversed(list(statesdf['state'][:10]))), list(reversed(list(statesdf['counts'][:10]))), "Principales Ciudades con Más Donantes", '#a8a1a3', 600, 400, 200, limit = 10, rt=True)
trace2 = bar_hor_noagg(list(reversed(list(citydf['state'][:10]))), list(reversed(list(citydf['counts'][:10]))), "Principales Estados con Más Donantes", '#a8a1a3', 600, 400, 200, limit = 10, rt=True)

fig = tools.make_subplots(
    rows=1, 
    cols=2, 
    print_grid=False, 
    subplot_titles=[
        'Estados y Promedio de Montos Donados',
        'Ciudades y Promedio de Montos Donados'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig['layout'].update(height=400, showlegend=False)
iplot(fig)

# %% [markdown]
# > - **Monto promedio de las donaciones:**
# > - **Hawái** y **Massachusetts** registran los **montos promedio de donación más altos** entre todos los estados.
# > - Las ciudades de **Clarks Point**, **Swiftwater** y **North English** destacan por presentar los **montos promedio de donación más elevados**.
#
# ## <a id="3.8">3.8 Monto Total de Donaciones Recibidas por Estado</a>

# %%
from io import StringIO
import pandas as pd
import folium

# Coordenadas de los estados
statesll = StringIO("""State,Latitude,Longitude
Alabama,32.806671,-86.791130
Alaska,61.370716,-152.404419
Arizona,33.729759,-111.431221
Arkansas,34.969704,-92.373123
California,36.116203,-119.681564
Colorado,39.059811,-105.311104
Connecticut,41.597782,-72.755371
Delaware,39.318523,-75.507141
District of Columbia,38.897438,-77.026817
Florida,27.766279,-81.686783
Georgia,33.040619,-83.643074
Hawaii,21.094318,-157.498337
Idaho,44.240459,-114.478828
Illinois,40.349457,-88.986137
Indiana,39.849426,-86.258278
Iowa,42.011539,-93.210526
Kansas,38.526600,-96.726486
Kentucky,37.668140,-84.670067
Louisiana,31.169546,-91.867805
Maine,44.693947,-69.381927
Maryland,39.063946,-76.802101
Massachusetts,42.230171,-71.530106
Michigan,43.326618,-84.536095
Minnesota,45.694454,-93.900192
Mississippi,32.741646,-89.678696
Missouri,38.456085,-92.288368
Montana,46.921925,-110.454353
Nebraska,41.125370,-98.268082
Nevada,38.313515,-117.055374
New Hampshire,43.452492,-71.563896
New Jersey,40.298904,-74.521011
New Mexico,34.840515,-106.248482
New York,42.165726,-74.948051
North Carolina,35.630066,-79.806419
North Dakota,47.528912,-99.784012
Ohio,40.388783,-82.764915
Oklahoma,35.565342,-96.928917
Oregon,44.572021,-122.070938
Pennsylvania,40.590752,-77.209755
Rhode Island,41.680893,-71.511780
South Carolina,33.856892,-80.945007
South Dakota,44.299782,-99.438828
Tennessee,35.747845,-86.692345
Texas,31.054487,-97.563461
Utah,40.150032,-111.862434
Vermont,44.045876,-72.710686
Virginia,37.769337,-78.169968
Washington,47.400902,-121.490494
West Virginia,38.491226,-80.954453
Wisconsin,44.268543,-89.616508
Wyoming,42.755966,-107.302490""")

# Total donado por estado
tempdf = (
    combined_df.groupby('Donor State')['Donation Amount']
    .sum()
    .reset_index()
    .sort_values('Donation Amount', ascending=False)
)

# Unir con coordenadas
sdf = pd.read_csv(statesll).rename(columns={'State':'Donor State'})
sdf = sdf.merge(tempdf, on='Donor State', how='inner')

# Crear mapa
map4 = folium.Map(
    location=[39.50, -98.35],
    zoom_start=4,
    tiles='CartoDB dark_matter'
)

# Valor máximo
max_amount = sdf['Donation Amount'].max()

# Agregar círculos
for _, row in sdf.iterrows():

    # Escala automática
    radius = (row['Donation Amount'] / max_amount) * 35

    # Radio mínimo
    if radius < 3:
        radius = 3

    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=radius,
        popup=f"""
        <b>Estado:</b> {row['Donor State']}<br>
        <b>Total donado:</b> ${row['Donation Amount']:,.0f}
        """,
        color='blue',
        weight=2,
        fill=True,
        fill_color='blue',
        fill_opacity=0.25
    ).add_to(map4)

map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ## <a id="3.9">3.9 Evolución de las Donaciones en California a lo Largo del Tiempo</a>
#
# Analicemos la tendencia de las donaciones realizadas en **California** a lo largo de los años.

# %%
combined_df['Donation Date'] = combined_df['Donation Received Date'].apply(lambda x : str(x).split()[0])

cali = combined_df[combined_df['Donor State'] == 'California']
cali = cali.groupby('Donation Date').agg({'Donation Amount' : 'count'}).reset_index()
cali1 = pd.DataFrame()
cali1['Date'] = pd.to_datetime(cali['Donation Date']) 
cali1['Donation Amount'] = cali['Donation Amount']

trace1 = go.Scatter(x=cali1['Date'], y=cali1['Donation Amount'], name = "California", line = dict(color = 'red'), opacity = 0.8)

data = [trace1]
layout = dict(
    title="Donaciones de California a lo Largo del Tiempo", 
    height=400, 
    showlegend=False, 
    yaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
        ticks=''
    )
)
fig = dict(data=data, layout=layout)
iplot(fig)

# %% [markdown]
# > El número máximo de donaciones de California se registró el **25 de enero de 2018** con casi 5,000 donaciones, seguido por el **28 de noviembre de 2017** con 4,699 donaciones
#
# ## <a id="4"> 4. Exploración de Maestros  </a>
# ## <a id="4.1"> 4.1 Resumen de Datos de Maestros </a>

# %%
# Mostrar las primeras 3 filas de maestros
teachers_df.head(3)

# len(teachers_df)  # Número total de maestros en el dataset
# Out:
#                          Teacher ID Teacher Prefix  \
# 0  bdd640fb06671ad11c80317fa3b1799d           Mrs.
# 1  ad3c2d6d1a3d1fa7bc8960a923b8c1e9            Ms.
# 2  0822e8f36c031199972a846916419f82           Mrs.
#
#   Teacher First Project Posted Date
# 0                        2007-01-03
# 1                        2014-03-26
# 2                        2006-11-27

# %% [markdown]
# > Hay un total de **402,900 maestros** que han publicado al menos un proyecto en DonorsChoose desde el año **2002**. Una gran mayoría de los maestros son **mujeres**, veamos cuáles fueron los primeros maestros que publicaron proyectos en DonorsChoose.
#
# ## <a id="4.2"> 4.2 ¿Quiénes fueron los Primeros Maestros en DonorsChoose.org? </a>

# %%
teachers_df['Posted Date'] = pd.to_datetime(teachers_df['Teacher First Project Posted Date'])
teachers_df['Posted Year'] = teachers_df['Posted Date'].dt.year

# Descubramos quiénes fueron los primeros maestros en DonorsChoose
# Algunos de los maestros más antiguos
teachers_df[['Teacher ID', 'Posted Date']].sort_values(['Posted Date'])[:10]
# Out:
#                            Teacher ID Posted Date
# 29   6f4cc69a4b22d3081c8eaee95715bd6f  2002-01-27
# 78   d450281c6c6f7633a260772317a0df49  2002-01-30
# 114  25c73c443e75c3b4664fa6637e8f8095  2002-02-15
# 68   c07a30f2edd4253b50f0fd0a750cab75  2002-03-18
# 80   b4a69f3c8d3aed99711c21c9bdc14f1f  2002-03-21
# 54   ffd0f9d5a6f2f7b80cf35b5819108be5  2002-05-01
# 162  b63b4dc3a559e46379e13ceab0cbc61f  2002-05-22
# 42   3985c3cf3f76be1d1efa21977394988f  2002-06-22
# 87   2d534dd0cf8ebc5accc56569f9e8a369  2002-07-23
# 95   89456f27d7fa2d8dfb2ca025adf4e62d  2002-08-15

# %% [markdown]
# > Los primeros maestros en DonorsChoose se registraron el **2002-09-17**. En este día se registraron **2 maestros**, ambas mujeres. En el mes de **septiembre de 2002**, se registraron un total de **8 maestros**, quienes fueron principalmente el primer grupo de maestros en DonorsChoose.
#
# ## <a id="4.3"> 4.3 Crecimiento en el Número de Maestros a lo Largo de los Años </a>

# %%
temp = teachers_df.groupby('Posted Year').agg({'Teacher ID' : 'count'}).reset_index()
temp = temp.sort_values('Posted Year')

trace = go.Scatter(
    x=list(temp['Posted Year'])[:-1],
    y=list(temp['Teacher ID'])[:-1],
    mode='lines+markers',  # ← CORREGIDO: "markers" en plural
    line=dict(color="#42e5f4", width=8),
    connectgaps=True,
    fillcolor='rgba(0,100,80,0.2)',
)

layout = go.Layout(
    xaxis=dict(
        showline=True,
        showgrid=False,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickcolor='rgb(204, 204, 204)',
        tickwidth=2,
        ticklen=5,
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    title='Número de Maestros que Comenzaron a Publicar sus Proyectos por Año'
)

fig = go.Figure(data=[trace], layout=layout)
iplot(fig, filename='news-source')

# %% [markdown]
# > - El número de maestros comenzó a publicar en DonorChoose cuando se lanzó en **2002**, pero los primeros cinco años tuvieron muy pocos maestros publicando proyectos.
# > - Una tendencia creciente comenzó a desarrollarse alrededor de **2008** y el período **2012 - 2013** vio un aumento masivo en el número de maestros publicando proyectos.
# > - La tendencia alcanzó el punto máximo de **80K** nuevos maestros publicando proyectos en **2016**, pero el número disminuyó a **75K en 2017**. No solo los donantes necesitan ser motivados, sino que también los maestros necesitan ser promovidos para publicar más proyectos. Al observar el crecimiento de nuevos maestros a lo largo de los años, parece que DonorChoose está haciendo un buen trabajo.
#
# ## <a id="4.4"> 4.4 ¿Cuál es la Distribución de los Prefijos de Maestros? </a>

# %%
t = teachers_df['Teacher Prefix'].value_counts()

labels = t.index
values2 = t.values

# Colores para cada categoría de prefijo
trace2 = go.Pie(
    labels=labels, 
    values=values2, 
    marker=dict(colors=['#75e575', '#ea7c96', '#7cc9ea', '#f4b860', '#a875e5', '#e57575'])
)

layout = go.Layout(
    title='Distribución de Prefijos de Maestros', 
    width=800, 
    height=500
)
fig = go.Figure(data=[trace2], layout=layout)
iplot(fig)

# %% [markdown]
# ## <a id="4.5"> 4.5 Serie Temporal de Maestros Publicando sus Primeros Proyectos </a>

# %%
t = teachers_df['Posted Date'].value_counts()
x = t.index
y = t.values

# Crear gráfica de barras con Plotly nativo y naranja más intenso
trace = go.Bar(
    x=x,
    y=y,
    marker=dict(color='#FF8C00')  # Naranja oscuro más intenso
)

layout = go.Layout(
    title='Fecha y Primeros Proyectos de Maestros',
    xaxis=dict(title='Fecha'),
    yaxis=dict(title='Número de Maestros')
)

fig = go.Figure(data=[trace], layout=layout)
iplot(fig)

# %% [markdown]
# > - El número más alto de proyectos por primera vez se observó el **13 de septiembre de 2015 con 2,067 proyectos**.
# > - Es interesante notar que se observan picos cada **agosto** de **2014 a 2017**.
#
# ## <a id="5"> 5. Exploración de Escuelas </a>
# ## <a id="5.1"> 5.1 Resumen de Datos de Escuelas </a>

# %%
schools_df = pd.read_csv(path+"Schools.csv", on_bad_lines='skip')

# Renombrar columnas a español
schools_df = schools_df.rename(columns={
    'School ID': 'ID de Escuela',
    'School Name': 'Nombre de Escuela',
    'School Metro Type': 'Tipo de Zona Metropolitana',
    'School Percentage Free Lunch': 'Porcentaje de Almuerzo Gratuito',
    'School State': 'Estado de la Escuela',
    'School Zip': 'Código Postal',
    'School City': 'Ciudad de la Escuela',
    'School County': 'Condado de la Escuela',
    'School District': 'Distrito Escolar'
})

schools_df.head(3)

# len(schools_df)  # Número total de escuelas en el dataset
# Out:
#                       ID de Escuela            Nombre de Escuela  \
# 0  bdd640fb06671ad11c80317fa3b1799d      Miami Elementary School
# 1  07a0ca6e0822e8f36c031199972a8469    Houston Elementary School
# 2  a65ed389b74d0fb132e706298fadc1a6  Sammamish Elementary School
#
#   Tipo de Zona Metropolitana  Porcentaje de Almuerzo Gratuito  \
# 0                      urban                             17.0
# 1                      urban                             64.0
# 2                       town                             75.0
#
#   Estado de la Escuela  Código Postal Ciudad de la Escuela  \
# 0              Florida          23434                Miami
# 1                Texas          88907              Houston
# 2           Washington          46463            Sammamish
#
#   Condado de la Escuela           Distrito Escolar
# 0          Miami County      Miami School District
# 1        Houston County    Houston School District
# 2      Sammamish County  Sammamish School District

# %% [markdown]
# > Se han publicado proyectos de un total de **72,993 escuelas diferentes** en DonorsChoose hasta **abril de 2018**.
#
# ## <a id="5.2"> 5.2 ¿Qué Tipo de Zona Metropolitana de las Escuelas Publica Proyectos (y Principales Estados y Ciudades)? </a>

# %%
# Volver a cargar sin renombrar
schools_df = pd.read_csv(path+"Schools.csv", on_bad_lines='skip')

# Ahora sí funciona con los nombres en inglés
t1 = schools_df['School Metro Type'].value_counts()
t2 = schools_df['School State'].value_counts()
t3 = schools_df['School City'].value_counts()

trace1 = bar_ver_noagg(t1.index[:10], t1.values[:10], "Tipo de Zona Metropolitana", '#e56eb5', None, None, 0, rt=True)
trace2 = bar_ver_noagg(t2.index[:10], t2.values[:10], "Principales Estados con Más Escuelas", '#e88de8', None, None, 0, rt=True)
trace3 = bar_ver_noagg(t3.index[:10], t3.values[:10], "Principales Ciudades con Más Escuelas", '#efc4ef', None, None, 0, rt=True)

fig = tools.make_subplots(
    rows=1, 
    cols=3, 
    print_grid=False, 
    subplot_titles=[
        'Tipo de Zona Metropolitana', 
        'Principales Estados con Más Escuelas', 
        'Principales Ciudades con Más Escuelas'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig['layout'].update(height=400, showlegend=False)
iplot(fig)

# %% [markdown]
# > - La mayoría de las escuelas se encuentran en **zonas suburbanas y urbanas**.
# > - **Nueva York**, **Houston** y **Chicago** son las tres ciudades principales donde se ubican las escuelas.
#
# ## <a id="5.3"> 5.3 Distribución del Porcentaje de Almuerzo Gratuito en las Escuelas </a>

# %%
# extraer Tipos de Escuelas
plt.figure(figsize=(15,5))
sns.distplot(schools_df['School Percentage Free Lunch'].dropna(), bins=120, color="#ff002e")
plt.xlabel('Porcentaje de Almuerzo Gratuito', fontsize=14)
plt.title("Distribución del Porcentaje de Almuerzo Gratuito en las Escuelas", fontsize=14)
plt.show()

# %% [markdown]
# ## <a id="5.4"> 5.4 ¿Qué Tipos de Escuelas Están Registrados en Mayoría? </a>

# %%
words = " ".join(schools_df['School Name']).split()
from collections import Counter

school_types = Counter(words).most_common(30)[1:9]
school_types = [list(x) for x in school_types]

# Diccionario de traducción de tipos de escuela
traduccion = {
    'Elementary': 'Escuela Primaria',
    'High': 'Escuela Preparatoria',
    'Middle': 'Escuela Secundaria',
    'Academy': 'Academia',
    'Charter': 'Escuela Charter',
    'Center': 'Centro Escolar',
    'Junior': 'Escuela Junior',
    'Senior': 'Escuela Senior'
}

# Usar traducción o mantener original si no está en el diccionario
labels = [traduccion.get(x[0], x[0]) for x in school_types]
values = [x[1] for x in school_types]

trace2 = go.Bar(
    x=labels,
    y=values,
    name='Cantidad de Escuelas',
    marker=dict(color='#ff00bb'),
    opacity=0.3
)

data = [trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    title='Distribución de Tipos de Escuelas',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')

# %% [markdown]
# > Una gran mayoría de las escuelas son **Escuelas Primarias** (con aproximadamente **35K** escuelas), lo cual es mucho mayor que las **Escuelas Preparatorias** (aproximadamente **12K** escuelas), **Escuelas Secundarias** (aproximadamente **9K** escuelas) o **Academias Escolares** (aproximadamente **4K** escuelas).
#
# ## <a id="6"> 6. Exploración de Recursos </a>
#
# Los datos de recursos consisten en artículos solicitados bajo diferentes proyectos, lo cual incluye nombre del artículo, cantidad de recursos, precio unitario y nombre del proveedor.
#
# ## <a id="6.1"> 6.1 Resumen de Recursos </a>

# %%
resources_df = pd.read_csv(path+"Resources.csv")

# Renombrar columnas a español
resources_df = resources_df.rename(columns={
    'Project ID': 'ID de Proyecto',
    'Resource Item Name': 'Nombre del Artículo',
    'Resource Quantity': 'Cantidad de Recursos',
    'Resource Unit Price': 'Precio Unitario',
    'Resource Vendor Name': 'Nombre del Proveedor'
})

resources_df.head(5)

# len(resources_df)  # Número total de recursos en el dataset
# Out:
#                      ID de Proyecto  \
# 0  bdd640fb06671ad11c80317fa3b1799d
# 1  f143262fdc5c0eed8da0365bf89897b9
# 2  451b4cf36123fdf77656af7229d4beef
# 3  0e51f30dc6a7ee39c4b032ccd7c524a5
# 4  0e51f30dc6a7ee39c4b032ccd7c524a5
#
#                          Nombre del Artículo  Cantidad de Recursos  \
# 0  gaiam kids stay-n-play balance ball, grey                  44.0
# 1                      apple ipad wi-fi 32gb                   8.0
# 2              sony mdr zx100 blk headphones                  17.0
# 3  gaiam kids stay-n-play balance ball, grey                  41.0
# 4              serta lounger, mini, sky blue                  10.0
#
#    Precio Unitario          Nombre del Proveedor
# 0           398.73  Lakeshore Learning Materials
# 1           135.61               Amazon Business
# 2           437.49               Amazon Business
# 3           137.81                           NaN
# 4           171.39               Amazon Business

# %% [markdown]
# > Hasta **abril de 2018**, se han realizado un total de **7,210,448 solicitudes de recursos** por parte de maestros en diferentes proyectos.
#
# ## <a id="6.2"> 6.2 Artículos Más Populares </a>
#
# Obtengamos cuáles son los artículos más populares de los datos de recursos. Los artículos más solicitados son aquellos que aparecieron en un gran número de proyectos. Los artículos solicitados en grandes cantidades representan aquellos que fueron pedidos en números elevados.
#
# - 6.2.1 Artículos más solicitados de todos los tiempos
# - 6.2.2 Artículos solicitados en grandes cantidades

# %%
# Usar nombres de columnas en español (ya renombrados anteriormente)
tdf = resources_df['Nombre del Artículo'].value_counts()[:15]
t = pd.DataFrame()
t['item'] = tdf.index 
t['count'] = tdf.values
t['standardized'] = list(reversed("""Kids Stay N Play Ball, Apple Ipad, HP 11'6 Chromebook, Black write and wipe markers , Kids Stay N Play Ball, Soft Seats, Privacy Partition, Apple Ipad, Commercial Furniture, Apple Ipad, Apple Ipad, Noise, Apple Ipad, Noise, Trip""".split(",")))
t1 = t.groupby('standardized').agg({'count' : 'sum'}).reset_index()
t1 = t1.sort_values('count', ascending = True)
t1 = t1[t1['standardized'] != " Noise"]
trace1 = bar_ver_noagg(list(reversed(list(t1['standardized']))), list(reversed(list(t1['count']))), "Artículos de Recursos Más Solicitados", "#ff5479", 400, 400, 0, rt=True)

t = resources_df.sort_values('Cantidad de Recursos', ascending=False).head(10)
trace2 = bar_ver_noagg(t['Nombre del Artículo'], t['Cantidad de Recursos'], "Artículos de Recursos Más Costosos", "#fc839d", 600, 400, 0, rt=True)

fig = tools.make_subplots(
    rows=1, 
    cols=2, 
    print_grid=False, 
    subplot_titles=['Artículos Más Solicitados', 'Artículos Solicitados en Grandes Cantidades']
)
fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig['layout'].update(height=400, showlegend=False, margin=dict(b=120))
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 6
#       4 t['item'] = tdf.index
#       5 t['count'] = tdf.values
# ----> 6 t['standardized'] = list(reversed("""Kids Stay N Play Ball, Apple Ipad, HP 11'6 Chromebook, Black write and wipe markers , Kids Stay N Play Ball, Soft Seats, Privacy Partition, Apple Ipad, Commercial Furniture, Apple Ipad, Apple Ipad, Noise, Apple Ipad, Noise, Trip""".split(",")))
#       7 t1 = t.groupby('standardized').agg({'count' : 'sum'}).reset_index()
#       8 t1 = t1.sort_values('count', ascending = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# ...

# %% [markdown]
# > Como podemos ver, el **Apple iPad** (iPad Mini, Wifi, 16 o 32 GB) es el artículo más solicitado de todos los tiempos. Fue solicitado en más de **30 mil proyectos**. Los maestros están muy interesados en usar tecnología en las aulas. Los **Viajes** son otro de los artículos más solicitados de todos los tiempos con más de **20K proyectos**, lo que significa que los maestros están interesados en llevar a los estudiantes a viajes educativos o culturales. Otros artículos principales incluyen **Particiones de Privacidad**, **Mobiliario Comercial** y **Asientos Suaves**.
#
# > Hay muchos artículos que fueron solicitados en grandes cantidades en uno o más proyectos. Algunos artículos incluyen **Bloques Transversales de Polietileno**, **Q-Ball Renewal Glide** y **Glide para Sillas**.
#
# ## <a id="6.3"> 6.3 Artículos Más Costosos </a>

# %%
# Usar nombres de columnas en español (ya renombrados anteriormente)
t = resources_df.sort_values('Precio Unitario', ascending=False).head(15)
t1 = pd.DataFrame()
t1['item'] = t['Nombre del Artículo']
t1['price'] = t['Precio Unitario']
t1['standardized'] = """Handicapped Playground,Playground,CommercialStructure,Telescopic Gym,Playground+Playsystem,Sound System,CommercialStructure,Wood Playground,Playground+Playsystem,10 Alpha,Leveled Bookroom,Daktronic GS6,Contra Bassoon,Fencing,Playground+Playsystem""".split(",")
t2 = t1.groupby('standardized').agg({'price' : 'max'}).reset_index()
t2 = t2.sort_values('price', ascending = True)
trace2 = bar_ver_noagg(list(reversed(list(t2['standardized']))), list(reversed(list(t2['price']))), "Artículos de Recursos Más Costosos", "#69efbc", 800, 400, 100)

# %% [markdown]
# > - Mientras se compara el costo promedio recibido por un proveedor, **MarkerBot** llega a la cima con el costo promedio por proyecto recibido de **USD 2,000**.
# > - **Best Buy Education** es uno de esos proveedores que es popular entre los maestros y también tiene un precio promedio recibido por proyecto significativamente más alto.
#
# ## <a id="6.4"> 6.4 Proveedores Famosos en DonorsChoose </a>

# %%
## <a id="6.4"> 6.4 Proveedores Famosos en DonorsChoose </a>

# Proveedores más famosos (top 15)
t = resources_df['Nombre del Proveedor'].value_counts()
k = list(reversed(list(t.index)[:15]))
v = list(reversed(list(t.values)[:15]))

# Gráfica de barras horizontales de proveedores más famosos
trace2 = bar_hor_noagg(k, v, "Proveedores Más Famosos", "#4cc0ff", 800, 500, 200, rt=True)

# Calcular precio total por recurso
resources_df['Precio Total'] = resources_df['Cantidad de Recursos'] * resources_df['Precio Unitario']

# Precio promedio recibido por cada proveedor
tempdf = resources_df.groupby('Nombre del Proveedor').agg({'Precio Total': 'mean'}).reset_index()
tempdf = tempdf.sort_values('Precio Total', ascending=False)[:15]
trace1 = bar_hor_noagg(
    list(reversed(list(tempdf['Nombre del Proveedor']))), 
    list(reversed(list(tempdf['Precio Total']))), 
    "", 
    "#c1e2f4", 
    800, 
    400, 
    200, 
    rt=True
)

# Crear subplots
fig = tools.make_subplots(
    rows=1, 
    cols=2, 
    print_grid=False, 
    subplot_titles=[
        "Cantidad Total de Proveedores", 
        "Monto Promedio por Proyecto del Proveedor"
    ]
)

fig.append_trace(trace2, 1, 1)
fig.append_trace(trace1, 1, 2)
fig['layout'].update(height=600, showlegend=False, margin=dict(l=250))
iplot(fig)

# %% [markdown]
# > - La mayoría de los recursos se solicitan a **Amazon Business, con 3.2 millones** de solicitudes de artículos. Amazon Business es seguido por Lakeshore Learning Materials y AKJ Education.
# > - Al comparar el costo promedio recibido por un proveedor, **MarkerBot** ocupa el primer lugar con un costo promedio por proyecto recibido de **USD 2,000**.
# > - **Best Buy Education** es un proveedor popular entre los maestros y también tiene un precio promedio recibido por proyecto significativamente más alto.
# <br>
#
# ## <a id="7"> 7. Exploración de Proyectos </a>
#
# Los datos de los proyectos consisten en todos los detalles sobre los proyectos publicados, que incluyen el ID del maestro y la escuela, título, tipo, categoría, costo, etc. Echemos un vistazo al resumen.
#
# ## <a id="7.1"> 7.1 Resumen de Proyectos </a>

# %%
# Cargar el conjunto de datos de proyectos
projects_df = pd.read_csv(path+"Projects.csv")

# Renombrar columnas a español
projects_df = projects_df.rename(columns={
    'Project ID': 'ID de Proyecto',
    'Teacher ID': 'ID de Maestro',
    'School ID': 'ID de Escuela',
    'Project Title': 'Título del Proyecto',
    'Project Essay': 'Ensayo del Proyecto',
    'Project Subject Category Tree': 'Categoría de Asunto del Proyecto',
    'Project Subject Subcategory Tree': 'Subcategoría de Asunto del Proyecto',
    'Project Resource Category': 'Categoría de Recursos del Proyecto',
    'Project Grade Level Category': 'Categoría de Nivel de Grado del Proyecto',
    'Project Price (including optional support)': 'Precio del Proyecto (incluyendo soporte opcional)',
    'Project Cost': 'Costo del Proyecto',
    'Project Posted Date': 'Fecha de Publicación del Proyecto',
    'Project Fully Funded Date': 'Fecha de Financiamiento Completo',
    'Project Current Status': 'Estado Actual del Proyecto'
})

# Mostrar las primeras 3 filas
projects_df.head(3)

# len(projects_df)  # Número total de proyectos en el dataset
# Out:
#                      ID de Proyecto                     ID de Escuela  \
# 0  bdd640fb06671ad11c80317fa3b1799d  23b8c1e9392456de3eb13b9046685257
# 1  32e706298fadc1a606cb0fb39a1de644  8b8148f6b38a088ca65ed389b74d0fb1
# 2  d8f564135be6128e18c267976142ea7d  ce9ff57f43b7a3a69a8dca03580d7b71
#
#                       ID de Maestro  Teacher Project Posted Sequence  \
# 0  bd9c66b3ad3c2d6d1a3d1fa7bc8960a9                                5
# 1  96da1dac72ff5d2a386ecbe06b65a6a4                                3
# 2  89463e85759cde66bacfb3d00b1f9163                                1
#
#   Project Type           Título del Proyecto  \
# 0  Teacher-Led  Anti-Bullying Begins with Me
# 1  Teacher-Led  Anti-Bullying Begins with Me
# 2  Teacher-Led   Technology in the Classroom
#
#                               Ensayo del Proyecto  \
# 0  Lorem ipsum dolor sit amet classroom school...
# 1  Lorem ipsum dolor sit amet classroom school...
# 2  Lorem ipsum dolor sit amet classroom school...
#
# ...

# %% [markdown]
# ## <a id="7.2"> 7.2 Categorías, Subcategorías y Categorías de Recursos Más Frecuentes </a>

# %%
# Crear características de fecha y hora
projects_df['Fecha de Publicación'] = pd.to_datetime(projects_df['Fecha de Publicación del Proyecto'])

projects_df['Año de Publicación'] = projects_df['Fecha de Publicación'].dt.year
projects_df['Mes de Publicación'] = projects_df['Fecha de Publicación'].dt.month
projects_df['Día de Publicación'] = projects_df['Fecha de Publicación'].dt.weekday
projects_df['Trimestre de Publicación'] = projects_df['Fecha de Publicación'].dt.quarter

projects_df['Fecha de Financiamiento'] = pd.to_datetime(projects_df['Fecha de Financiamiento Completo'])
projects_df['Año de Financiamiento'] = projects_df['Fecha de Financiamiento'].dt.year
projects_df['Mes de Financiamiento'] = projects_df['Fecha de Financiamiento'].dt.month
projects_df['Día de Financiamiento'] = projects_df['Fecha de Financiamiento'].dt.weekday
projects_df['Trimestre de Financiamiento'] = projects_df['Fecha de Financiamiento'].dt.quarter
projects_df['Tiempo de Financiamiento'] = projects_df['Fecha de Financiamiento'] - projects_df['Fecha de Publicación']

# Obtener las categorías de asunto más frecuentes
t = projects_df['Categoría de Asunto del Proyecto'].value_counts()
x = list(t.index)
y = list(t.values)
r = {}
for i, val in enumerate(x):
    for each in val.split(","):
        x1 = each.strip()
        if x1 not in r:
            r[x1] = y[i]
        r[x1] += y[i]
sorted_x = list(sorted(r.items(), key=operator.itemgetter(1), reverse=True))[:10]
x1 = [a[0] for a in sorted_x][::-1]
y1 = [a[1] for a in sorted_x][::-1]

# Obtener las subcategorías de asunto más frecuentes
t1 = projects_df['Subcategoría de Asunto del Proyecto'].value_counts()
x2 = list(t1.index)
y2 = list(t1.values)
r = {}
for i, val in enumerate(x2):
    for each in val.split(","):
        x1_ = each.strip()
        if x1_ not in r:
            r[x1_] = y2[i]
        r[x1_] += y2[i]
x2 = r.keys()
y2 = r.values()
sorted_x = list(sorted(r.items(), key=operator.itemgetter(1), reverse=True))[:10]
x2 = [a[0] for a in sorted_x][::-1]
y2 = [a[1] for a in sorted_x][::-1]

# Obtener las categorías de recursos más frecuentes
t = projects_df['Categoría de Recursos del Proyecto'].value_counts()
x3 = list(t.index[::-1])[:10]
y3 = list(t.values[::-1])[:10]

# Crear las tres gráficas de barras horizontales
trace1 = bar_hor_noagg(x1, y1, "", "#8cf2a9", 600, 400, 10, rt=True)
trace2 = bar_hor_noagg(x2, y2, "", "#8cf2a9", 600, 400, 10, rt=True)
trace3 = bar_hor_noagg(x3, y3, "", "#8cf2a9", 600, 400, 10, rt=True)

# Crear subplots con títulos en español
fig = tools.make_subplots(
    rows=1, 
    cols=5, 
    print_grid=False, 
    subplot_titles=[
        'Categorías de Proyecto', 
        "", 
        'Subcategorías de Proyecto', 
        '', 
        "Categorías de Recursos"
    ]
)
fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 3)
fig.append_trace(trace3, 1, 5)
fig['layout'].update(height=400, showlegend=False, margin=dict(l=120))
iplot(fig)

# %% [markdown]
# > Una gran mayoría de proyectos (más de 800K) pertenecen a la categoría principal de **Alfabetización e Idiomas**. **Matemáticas y Ciencias** es la segunda categoría más popular. Un número comparativamente menor de proyectos se han publicado sobre Cuidado y Hunger desde 2013.
# > Entre las subcategorías, Alfabetización, Matemáticas y Escritura son las subcategorías más comunes de los proyectos publicados por los maestros, mientras que un menor número de proyectos se publican bajo la categoría de Desarrollo Temprano y Salud.
# > **Tecnología Instruccional, Rincones de Lectura, Escritorios y Almacenamiento** son las categorías clave de recursos solicitados por los maestros.
#
# ## <a id="7.3"> 7.3 ¿Cuál es la Distribución del Tipo de Proyecto y el Estado Actual del Proyecto? </a>

# %%
# ==========================================
# PASO 1: Asegurar que las columnas necesarias existan en español
# ==========================================
# Mapeo de nombres en inglés a español para las columnas necesarias
cols_map_7_3 = {
    'Project Type': 'Tipo de Proyecto',
    'Project Current Status': 'Estado Actual del Proyecto'
}

# Renombrar solo las columnas necesarias (si ya están en español, no hace nada)
projects_df = projects_df.rename(columns=cols_map_7_3)

# ==========================================
# PASO 2: Generar la gráfica de dona
# ==========================================

# Tipo de Proyecto
t = projects_df['Tipo de Proyecto'].value_counts()
values1 = t.values 
index1 = t.index

# Estado Actual del Proyecto
t = projects_df['Estado Actual del Proyecto'].value_counts()
values2 = t.values 
index2 = t.index

domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}

fig = {
  "data": [
    {
      "values": values1,
      "labels": index1,
      "domain": {"x": [0, .48]},
      "marker": dict(colors=["#f77b9c", '#ab97db', '#b0b1b2']),
      "name": "Tipo de Proyecto",
      "hoverinfo": "label+percent+name",
      "hole": .7,
      "type": "pie"
    },
    {
      "values": values2,
      "labels": index2,
      "marker": dict(colors=["#efbc56", "#81a7e8", "#e295d0"]),
      "domain": {"x": [.52, 1]},
      "textposition": "inside",
      "name": "Estado del Proyecto",
      "hole": .7,
      "type": "pie"
    }
  ],
  "layout": {
    "annotations": [
      {
        "font": {"size": 20},
        "showarrow": False,
        "text": "Tipo",
        "x": 0.21,
        "y": 0.5
      },
      {
        "font": {"size": 20},
        "showarrow": False,
        "text": "Estado",
        "x": 0.8,
        "y": 0.5
      }
    ]
  }
}
iplot(fig, filename='donut')

# %% [markdown]
# > Además de los dominantes proyectos dirigidos por maestros, un número significativamente menor de proyectos también son publicados por estudiantes o servicios de desarrollo profesional. Los datos muestran que aproximadamente el **75%** de todos los proyectos publicados han sido completamente financiados, mientras que el **21%** de ellos han expirado. Hasta **mayo de 2018**, aproximadamente **42K** proyectos están activos en DonorsChoose.
#
# ## <a id="7.4"> 7.4 ¿En qué días se publicaron y financiaron la mayor cantidad de proyectos? </a>

# %%
# Días de publicación y financiamiento
t1 = projects_df['Día de Publicación'].value_counts()
t2 = projects_df['Día de Financiamiento'].value_counts()

# Mapeo de números a días de la semana en español
mapp = {0:'Dom', 1:'Lun', 2:'Mar', 3:'Mié', 4:'Jue', 5:'Vie', 6:'Sáb'}
values1 = t1.values 
index1 = t1.index
index1 = [mapp[x] for x in index1]

values2 = t2.values 
index2 = t2.index
index2 = [mapp[x] for x in index2]

# Crear mapeo para alinear los días de financiamiento con los días de publicación
tmap = {}
for j, b in enumerate(index2):
    tmap[b] = values2[j]

values2_c = [tmap[c] for c in index1]

domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}

fig = {
  "data": [
    {
      "values": values1,
      "labels": index1,
      "domain": {"x": [0, .48]},
      "marker": dict(colors=["#f77b9c", '#ab97db', '#b0b1b2', "#efbc56", "#81a7e8", "#e295d0"]),
      "name": "Día de Publicación",
      "hoverinfo": "label+percent+name",
      "hole": .7,
      "type": "pie"
    },
    {
      "values": values2_c,
      "labels": index1,
      "marker": dict(colors=["#f77b9c", '#ab97db', '#b0b1b2', "#efbc56", "#81a7e8", "#e295d0"]),
      "domain": {"x": [.52, 1]},
      "textposition": "inside",
      "name": "Día de Financiamiento",
      "hole": .7,
      "type": "pie"
    }
  ],
  "layout": {
    "annotations": [
      {
        "font": {
          "size": 20
        },
        "showarrow": False,
        "text": "Día de Publicación",
        "x": 0.17,
        "y": 0.5
      },
      {
        "font": {
          "size": 20
        },
        "showarrow": False,
        "text": "Día de Financiamiento",
        "x": 0.83,
        "y": 0.5
      }
    ]
  }
}
iplot(fig, filename='donut')

# %% [markdown]
# > Los maestros generalmente publican hacia el final de la semana: **viernes (16%)**, **sábados (16%)** y **domingos (17%)**. Por otro lado, los **lunes** es cuando se ha financiado y cerrado el mayor número de proyectos.
#
# ## <a id="7.5"> 7.5 ¿En qué Trimestres se Publican y Financian los Proyectos? </a>

# %%
# Trimestres de publicación y financiamiento
t1 = projects_df['Trimestre de Publicación'].value_counts()
t2 = projects_df['Trimestre de Financiamiento'].value_counts()

# Mapeo de números a trimestres en español
mappq = {1.0:'Trimestre 1', 2.0:'Trimestre 2', 3.0:'Trimestre 3', 4.0:'Trimestre 4'}
values1 = t1.values 
index1 = t1.index
index1 = [mappq[x] for x in index1]

values2 = t2.values 
index2 = t2.index
index2 = [mappq[x] for x in index2]

# Crear mapeo para alinear los trimestres de financiamiento con los trimestres de publicación
tmap = {}
for j, b in enumerate(index2):
    tmap[b] = values2[j]

values2_c = [tmap[c] for c in index1]

domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}

fig = {
  "data": [
    {
      "values": values1,
      "labels": index1,
      "domain": {"x": [0, .48]},
      "marker": dict(colors=["#f77b9c", '#ab97db', '#b0b1b2', "#efbc56", "#81a7e8", "#e295d0"]),
      "name": "Trimestre de Publicación",
      "hole": .7,
      "type": "pie"
    },
    {
      "values": values2_c,
      "labels": index1,
      "marker": dict(colors=["#f77b9c", '#ab97db', '#b0b1b2', "#efbc56", "#81a7e8", "#e295d0"]),
      "domain": {"x": [.52, 1]},
      "textposition": "inside",
      "name": "Trimestre de Financiamiento",
      "hole": .7,
      "type": "pie"
    }
  ],
  "layout": {
    "annotations": [
      {
        "font": {
          "size": 20
        },
        "showarrow": False,
        "text": "Publicado",
        "x": 0.2,
        "y": 0.5
      },
      {
        "font": {
          "size": 20
        },
        "showarrow": False,
        "text": "Financiado",
        "x": 0.8,
        "y": 0.5
      }
    ]
  }
}
iplot(fig, filename='donut')

# %% [markdown]
# > El **Trimestre 3** (julio, agosto, septiembre) es el período en el que se ha publicado el mayor número de proyectos por parte de los maestros, al igual que su trimestre inmediato siguiente, es decir, el **Trimestre 4**, cuando la mayoría de los proyectos han sido financiados y cerrados.
#
# ## <a id="7.6"> 7.6 ¿En qué Meses se Publican los Proyectos? </a>

# %%
# Mes de publicación de proyectos
t = projects_df['Mes de Publicación'].value_counts()

lObjectsALLcnts = list(t.values)
lObjectsALLlbls = list(t.index)

# Mapeo de números a meses en español
mapp1 = {1:'Ene', 2:'Feb', 3:'Mar', 4:'Abr', 5:'May', 6:'Jun', 
         7:'Jul', 8:'Ago', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dic'}
lObjectsALLlbls = [mapp1[x] for x in lObjectsALLlbls]

iN = len(lObjectsALLcnts)
arrCnts = np.array(lObjectsALLcnts)

theta = np.arange(0, 2*np.pi, 2*np.pi/iN)
width = (2*np.pi)/iN * 0.5
bottom = 50

fig = plt.figure(figsize=(8, 8))
ax = fig.add_axes([0.2, 0.1, 1, 0.9], polar=True)
fig.suptitle('Mes de Publicación de Proyectos', fontsize=16)
bars = ax.bar(theta, arrCnts, width=width, bottom=bottom, color='#f3a0f7')
plt.axis('off')

rotations = np.rad2deg(theta)
for x, bar, rotation, label in zip(theta, bars, rotations, lObjectsALLlbls):
    lab = ax.text(x, bottom+bar.get_height(), label, ha='left', va='center', 
                  rotation=rotation, rotation_mode="anchor")   
plt.show()

# %% [markdown]
# > En el **Trimestre 3**, el mayor número de proyectos se ha publicado en el mes de **septiembre**, seguido por **agosto**. El menor número de proyectos se ha publicado en **junio**.
#
# ## <a id="7.7"> 7.7 ¿En qué Año se Publicaron los Proyectos? </a>

# %%
# Agrupar proyectos por año de publicación
t = projects_df.groupby('Año de Publicación').agg({'Mes de Publicación': 'count'}).reset_index()
t = t.sort_values('Año de Publicación')

# Crear gráfica de barras verticales
trace2 = bar_ver_noagg(
    t['Año de Publicación'], 
    t['Mes de Publicación'], 
    "Proyectos Publicados por Año", 
    "#9887ed", 
    None, 
    400, 
    0
)

# %% [markdown]
# > El número de proyectos en DonorsChoose ha estado aumentando constantemente en los últimos 5 años. Aproximadamente **300K** proyectos se publicaron en **2017**.
#
# ## <a id="7.8"> 7.8 ¿En qué Año y Mes el Costo de los Proyectos es Más Alto? </a>

# %%
# Crear tabla de contingencia entre estado del proyecto y año de publicación
year_tab = pd.crosstab(projects_df["Estado Actual del Proyecto"], projects_df["Año de Publicación"]).reset_index()

from itertools import zip_longest

# Limpiar la columna de costo (eliminar comas y signo de dólar)
projects_df['costo'] = projects_df['Costo del Proyecto'].apply(lambda x: float(str(x).replace(",", "").replace("$", "")))

# Función para crear gráfica de burbujas (bubble chart)
def cbp(df, col1, col2, aggcol, func, title, cs, bottom_margin=None):
    # Agrupar por las dos columnas y calcular la agregación
    tempdf = df.groupby([col1, col2]).agg({aggcol: func}).reset_index()
    tempdf[aggcol] = tempdf[aggcol].apply(lambda x: int(x))
    tempdf = tempdf.sort_values(aggcol, ascending=False)

    # Crear tamaños de marcadores escalonados
    sizes = list(reversed([i for i in range(10, 31)]))
    intervals = int(len(tempdf) / len(sizes))
    size_array = [9] * len(tempdf)
    
    st = 0
    for i, size in enumerate(sizes):
        for j in range(st, st + intervals):
            size_array[j] = size 
        st = st + intervals
    
    tempdf['size_n'] = size_array
    cols = list(tempdf['size_n'])

    # Crear gráfica de dispersión con marcadores de diferentes tamaños
    trace1 = go.Scatter(
        x=tempdf[col1], 
        y=tempdf[col2], 
        mode='markers', 
        text=tempdf[aggcol],
        marker=dict(size=tempdf.size_n, color=cols, colorscale=cs)
    )
    
    data = [trace1]
    
    if bottom_margin:
        layout = go.Layout(title=title, margin=dict(b=150))
    else:
        layout = go.Layout(title=title)
    
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

# Llamar la función para graficar costo promedio por mes y año
cbp(projects_df, 'Mes de Publicación', 'Año de Publicación', 'costo', 'mean', 'Costo Promedio de Proyectos por Mes y Año', 'Picnic')

# %% [markdown]
# > - En **septiembre de 2014** se observó un gran número de proyectos publicados con un costo promedio alto. En **2015**, los meses de **abril, mayo, septiembre y octubre** tuvieron proyectos con un costo elevado.
#
# ## <a id="7.9"> 7.9 ¿En qué Año y Categoría de Grado el Costo de los Proyectos es Más Alto? </a>

# %%
# Gráfica de burbujas: Costo promedio por categoría de grado y año
cbp(projects_df, 'Categoría de Nivel de Grado del Proyecto', 'Año de Publicación', 'costo', 'mean', 'Costo Promedio de Proyectos por Categoría de Grado y Año', 'Earth')

# %% [markdown]
# > Para los grados 6-8 y 9-12, los proyectos con costos más altos se dieron en el año 2015; mientras que para los grados 3-5 y PreK-2, fueron en 2014.
#
# ## <a id="7.10"> 7.10 Categorías de Grado y Categorías de Recursos con los Costos de Proyecto Más Altos </a>

# %%
# Gráfica de burbujas: Costo promedio por categoría de recursos y categoría de nivel de grado
cbp(projects_df, 'Categoría de Recursos del Proyecto', 'Categoría de Nivel de Grado del Proyecto', 'costo', 'mean', 'Costo Promedio de Proyectos por Categoría de Recursos y Nivel de Grado', 'Picnic', bottom_margin=150)

# %% [markdown]
# > - Las excursiones se organizan principalmente para los grados superiores, es decir, de 9 a 12, seguidos por los de 6 a 8 y luego los de 3 a 5. Los grados de Preescolar a 2° (PreK-2) tienen un número significativamente menor en comparación con los otros grados. Los "Visitantes" son otro recurso clave solicitado para todos los grados.
#
# ## <a id="7.11"> 7.11 ¿Cómo Varía el Estado del Proyecto Según el Año? </a>

# %%
# Crear gráficas de pastel para cada año mostrando el estado de los proyectos
years = [2013, 2014, 2015, 2016, 2017, 2018]
plt.figure(figsize=(16, 10))

# Mapeo de estados de proyecto a español
estado_map = {
    'Fully Funded': 'Completamente Financiado',
    'Expired': 'Expirado',
    'Active': 'Activo'
}

for i, j in zip_longest(years, range(len(years))):
    plt.subplot(2, 3, j+1)
    
    # Obtener las etiquetas y traducirlas
    labels_originales = year_tab["Estado Actual del Proyecto"].tolist()
    labels_traducidos = [estado_map.get(label, label) for label in labels_originales]
    
    plt.pie(year_tab[i],
            labels=labels_traducidos,
            autopct="%1.0f%%", 
            colors=["#ff8ce0", "#9bf46b", "#4cdfef"],
            wedgeprops={"linewidth": 1, "edgecolor": "white"})
    plt.title(i)

# Agregar título general a la figura
plt.suptitle('Distribución del Estado de Proyectos por Año', fontsize=16, y=0.98)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2018
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 19
# ...

# %% [markdown]
# > Un análisis año por año de los datos muestra que **aproximadamente el 70% del total de proyectos** publicados en DonorsChoose en un año son completamente financiados. Ha habido una tendencia creciente en el porcentaje de proyectos financiados por año, **excepto en 2016**, cuando el número de proyectos completamente financiados disminuyó un 6% respecto al año anterior. 2017 y 2015 fueron los mejores años en términos de proporción de proyectos financiados, cuando aproximadamente el **78% de los proyectos** fueron financiados en su totalidad.
#
# ## <a id="7.12"> 7.12 ¿Por Cuántos Días Permanecieron Activos los Proyectos? </a>

# %%
# Filtrar proyectos completamente financiados
t = projects_df[projects_df['Estado Actual del Proyecto'] == "Fully Funded"]

# Extraer el número de días del tiempo de financiamiento
t['Tiempo de Financiamiento'] = t['Tiempo de Financiamiento'].apply(lambda x : int(str(x).split()[0]))

# Crear el histograma
plt.figure(figsize=(12,4))
ax = t['Tiempo de Financiamiento'].hist(bins=25, edgecolor='white', color="#e770f9")
ax.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel('Número de Días')
plt.title('Tiempo de Finalización de Proyectos Completamente Financiados')
plt.show()

# %% [markdown]
# > - Un gran número de proyectos tienen un tiempo de finalización de menos de 3 días. Aproximadamente <b>"55,000 proyectos"</b> en el pasado fueron financiados con éxito en un solo día, mientras que hay aproximadamente <b>"48,627 proyectos"</b> que se cerraron el mismo día en que fueron publicados. El mayor número de días para cualquier proyecto es de 288 días, correspondiente al proyecto titulado "**Empty Bowls, Full Hearts.**". Este proyecto tenía un costo estimado de USD 1,982 y fue publicado por la **Escuela Primaria Harrison Park** en Michigan.
#
# ## <a id="7.13"> 7.13 ¿Cómo Varía la Proporción de Proyectos Financiados vs No Financiados por Estado? </a>

# %%
# ==========================================
# SECCIÓN 7.13: Estado de los proyectos por estado
# ==========================================

# PASO 1: Renombrar columnas clave en AMBOS DataFrames para asegurar que coincidan
cols_merge = {
    'School ID': 'ID de Escuela',
    'School State': 'Estado de la Escuela',
    'Project Current Status': 'Estado Actual del Proyecto'
}

projects_df = projects_df.rename(columns=cols_merge)
schools_df = schools_df.rename(columns=cols_merge)

# PASO 2: Unir proyectos con escuelas (ahora ambas tablas tienen 'ID de Escuela')
projsch_df = projects_df.merge(schools_df, on="ID de Escuela")

# PASO 3: Lista de los 30 estados con más proyectos
states = ['California', 'Texas', 'New York', 'Florida', 'North Carolina',
       'Illinois', 'Georgia', 'South Carolina', 'Michigan',
       'Pennsylvania', 'Massachusetts', 'Indiana', 'Oklahoma',
       'Washington', 'Ohio', 'New Jersey', 'Missouri', 'Arizona',
       'Virginia', 'Louisiana', 'Tennessee', 'Utah', 'Wisconsin',
       'Connecticut', 'Alabama', 'Maryland', 'Nevada', 'Oregon',
       'Colorado', 'Mississippi', 'Minnesota', 'Kentucky', 'Arkansas',
       'Hawaii', 'Idaho', 'Maine', 'Kansas', 'Iowa',
        'New Mexico', 'West Virginia', 'Alaska',
       'New Hampshire', 'Delaware', 'Rhode Island', 'Nebraska',
       'South Dakota', 'Montana', 'North Dakota', 'Vermont', 'Wyoming'][:30]

import itertools
import matplotlib.pyplot as plt
import seaborn as sns

length = len(states)
plt.figure(figsize=(16, 24))

# PASO 4: Crear gráficas de barras para cada estado
for i, j in itertools.zip_longest(states, range(length)):
    plt.subplot(10, 6, j+1)
    
    # Contar estados de proyectos por estado (usando nombres en español)
    t = dict(projsch_df[projsch_df['Estado de la Escuela'] == i]['Estado Actual del Proyecto'].value_counts())

    # Calcular proyectos no financiados (Expirados)
    # Nota: Los VALORES de la columna no se renombraron, siguen siendo 'Expired' y 'Fully Funded'
    t['Not Funded'] = t.get('Expired', 0)
    t['Total'] = t.get('Fully Funded', 0) + t['Not Funded']
    
    # Calcular porcentajes (evitando división por cero)
    if t['Total'] > 0:
        t1 = {
            'Funded': float(t.get('Fully Funded', 0)) * 100 / t['Total'], 
            'Not Funded': float(t['Not Funded']) * 100 / t['Total']
        }
    else:
        t1 = {'Funded': 0, 'Not Funded': 0}

    # Crear gráfica de barras
    ax = sns.barplot(x=list(t1.keys()), y=list(t1.values()), alpha=.7, palette='cool')
    ax.grid(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.subplots_adjust(wspace=.8, hspace=1)
    plt.title(i, color="black")

plt.show()

# %% [markdown]
# > - Algunos de los estados donde el porcentaje de proyectos **Expirados o No Financiados** es menor son **"Georgia"**, **"Carolina del Sur"** y **"Misisipi"**.
#
# ## <a id="7.14"> 7.14 ¿Cuál es el Costo Promedio de los Proyectos según el Tipo de Área Metropolitana de la Escuela y la Categoría de Recursos Solicitados? </a>

# %%
# ==========================================
# SECCIÓN 7.14: Costo promedio por categoría de recursos y tipo de área metropolitana
# ==========================================

# PASO 1: Renombrar columnas clave en AMBOS DataFrames
cols_merge = {
    'School ID': 'ID de Escuela',
    'School Metro Type': 'Tipo de Zona Metropolitana',
    'Project Resource Category': 'Categoría de Recursos del Proyecto',
    'Project Cost': 'Costo del Proyecto'
}

projects_df = projects_df.rename(columns=cols_merge)
schools_df = schools_df.rename(columns=cols_merge)

# PASO 2: Hacer el merge asegurando que se incluyan todas las columnas
projsch_df = projects_df.merge(schools_df, on="ID de Escuela", how='inner')

# PASO 3: Crear la columna 'costo' si no existe (limpiando el formato de moneda)
if 'costo' not in projsch_df.columns:
    projsch_df['costo'] = projsch_df['Costo del Proyecto'].apply(
        lambda x: float(str(x).replace(",", "").replace("$", ""))
    )

# PASO 4: Verificar que las columnas necesarias existan
columnas_necesarias = ['Categoría de Recursos del Proyecto', 'Tipo de Zona Metropolitana', 'costo']
for col in columnas_necesarias:
    if col not in projsch_df.columns:
        print(f"⚠️ La columna '{col}' NO existe en projsch_df")
        print(f"   Columnas disponibles: {projsch_df.columns.tolist()}")
    else:
        print(f"✅ La columna '{col}' existe correctamente")

# PASO 5: Llamar a la función cbp para generar la gráfica de burbujas
cbp(
    projsch_df, 
    'Categoría de Recursos del Proyecto', 
    'Tipo de Zona Metropolitana', 
    'costo', 
    'mean', 
    'Costo Promedio de Proyectos por Categoría de Recursos y Tipo de Área Metropolitana', 
    'Rainbow', 
    bottom_margin=150
)

# %% [markdown]
# > Los viajes (*Trips*) y los visitantes (*Visitors*) son siempre las categorías más costosas entre todos los diferentes tipos de zonas metropolitanas escolares. Los "Pueblos" (*Towns*) tienen el costo promedio máximo para los proyectos en los que se solicitaron recursos pertenecientes a la categoría de Deportes y Equipos de Ejercicio.
#
# ## <a id="7.15"> 7.15 ¿Cuál es el Costo Promedio de los Proyectos según el Tipo de Zona Metropolitana de la Escuela y la Categoría de Nivel de Grado de los Proyectos? </a>

# %%
# Gráfica de burbujas: Costo promedio por categoría de nivel de grado y tipo de área metropolitana
cbp(
    projsch_df, 
    'Categoría de Nivel de Grado del Proyecto', 
    'Tipo de Zona Metropolitana',  # <-- Nombre corregido
    'costo', 
    'mean', 
    'Costo Promedio de Proyectos por Nivel de Grado y Tipo de Área Metropolitana', 
    'Rainbow'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 3
#       1 # Gráfica de burbujas: Costo promedio por categoría de nivel de grado y tipo de área metropolitana
#       2 cbp(
# ----> 3     projsch_df,
#       4     'Categoría de Nivel de Grado del Proyecto',
#       5     'Tipo de Zona Metropolitana',  # <-- Nombre corregido
#       6     'costo',
#       7     'mean',
#       8     'Costo Promedio de Proyectos por Nivel de Grado y Tipo de Área Metropolitana',
#       9     'Rainbow'
#      10 )
#
# NameError: name 'projsch_df' is not defined

# %% [markdown]
# > Los grados 9-12 tienen el costo promedio de proyectos más alto en comparación con cualquier otra categoría de grado. Entre ellos, los tipos de área metropolitana **Suburbana** tienen los precios de proyectos más altos, mientras que los **Pueblos** tienen los más bajos.
#
# ## <a id="8">8. Procesamiento de Lenguaje Natural para la Caracterización de Proyectos</a>
#
# Se puede construir mucho entendimiento mediante el análisis de texto de los Ensayos de Proyectos. Realicemos un análisis de texto básico / procesamiento de lenguaje natural para extraer la información relevante de los ensayos de los proyectos. Para este propósito, me enfoco en un subconjunto de proyectos recientes de **abril de 2018**.
#
# ## <a id="8.1">8.1 Limpieza de Texto</a>
#
# Escribamos una función utilitaria que normalice el texto y elimine el ruido. Esta función de limpieza de texto realiza la eliminación de palabras vacías (*stopwords*) del texto y la eliminación de signos de puntuación.

# %%
# ==========================================
# SECCIÓN 8.1: Limpieza de Texto (Todo en uno)
# ==========================================

# PASO 1: Instalar librerías necesarias (si no están instaladas)
# !pip install textblob nltk --quiet

# PASO 2: Importar librerías
from nltk.corpus import stopwords 
import nltk
import string 

# PASO 3: Descargar recursos de NLTK (stopwords)
nltk.download('stopwords', quiet=True)

# Cargar stopwords en inglés (los textos de los proyectos están en inglés)
stop_words = stopwords.words("english")

# PASO 4: Definir la función de limpieza de texto
def _clean(txt):
    """
    Función de limpieza de texto que normaliza y elimina ruido.
    Realiza: conversión a minúsculas, eliminación de puntuación, 
    eliminación de stopwords y palabras específicas de ruido.
    """
    if not isinstance(txt, str):
        return ""
        
    # Convertir a minúsculas
    txt = txt.lower()

    # Eliminar puntuación 
    txt = ''.join(x for x in txt if x not in string.punctuation)

    # Eliminar stopwords
    clean_txt = ""
    for word in txt.split():
        if word in stop_words:
            continue 
        clean_txt += " " + word 
    
    # Eliminar palabras específicas de ruido
    noise = ['students', 'my', 'title', 'would', 'every', 'will', 'many', 'also', 'donotremoveessaydivider']
    for ns in noise:
        clean_txt = clean_txt.replace(ns, "")

    return clean_txt

# PASO 5: Renombrar columnas necesarias (si no están ya en español)
projects_df = projects_df.rename(columns={
    'School ID': 'ID de Escuela',
    'Posted Year': 'Año de Publicación',
    'Posted Month': 'Mes de Publicación',
    'Project Essay': 'Ensayo del Proyecto',
    'Project Need Statement': 'Declaración de Necesidad'
})

schools_df = schools_df.rename(columns={
    'School ID': 'ID de Escuela'
})

# PASO 6: Unir proyectos con escuelas
projects_df = projects_df.merge(schools_df, on='ID de Escuela', how='inner')

# PASO 7: Filtrar proyectos de abril 2018
april18_df = projects_df[(projects_df['Año de Publicación'] == 2018) & (projects_df['Mes de Publicación'] == 4)].copy()

# PASO 8: Aplicar limpieza de texto a las columnas de ensayo y necesidad
print("🧹 Limpiando textos...")
april18_df['clean_essay'] = april18_df['Ensayo del Proyecto'].apply(_clean)
april18_df['clean_need'] = april18_df['Declaración de Necesidad'].apply(_clean)

print("✅ ¡Limpieza completada!")
print(f"Total de proyectos de abril 2018: {len(april18_df)}")

# Mostrar ejemplo de texto original vs limpio
print("\n--- Ejemplo de texto original vs limpio ---")
print("ORIGINAL:", april18_df['Ensayo del Proyecto'].iloc[0][:100], "...")
print("LIMPIO:  ", april18_df['clean_essay'].iloc[0][:100], "...")
# Out:
# 🧹 Limpiando textos...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Declaración de Necesidad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 71
# ...

# %% [markdown]
# ## <a id="8.2"> 8.2 Análisis de Bolsa de Palabras (Bag of Words) </a>
#
# ## <a id="8.2.1"> 8.2.1 ¿Cuáles son las palabras y frases principales utilizadas por los maestros en los ensayos? </a>

# %%
# ==========================================
# SECCIÓN 8.2.1: Análisis de Bolsa de Palabras (Bag of Words)
# ==========================================

from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Función para generar n-gramas a partir de una lista de palabras
def generate_ngrams(txt, N):
    grams = [txt[i:i+N] for i in range(len(txt)-N+1)]
    grams = [" ".join(b) for b in grams]
    return grams 

# Generar unigramas, bigramas y trigramas a partir del ensayo limpio
april18_df['unigrams'] = april18_df['clean_essay'].apply(lambda x: generate_ngrams(x.split(), 1))
april18_df['bigrams'] = april18_df['clean_essay'].apply(lambda x: generate_ngrams(x.split(), 2))
april18_df['trigrams'] = april18_df['clean_essay'].apply(lambda x: generate_ngrams(x.split(), 3))

# --- Procesamiento de Unigramas (Palabras individuales) ---
all_unigrams = []
for each in april18_df['unigrams']:
    all_unigrams.extend(each)
    
t = Counter(all_unigrams).most_common(25)
x = [a[0] for a in t]  # Palabras
y = [a[1] for a in t]  # Frecuencias

# --- Procesamiento de Bigramas (Pares de palabras) ---
all_bigrams = []
for each in april18_df['bigrams']:
    all_bigrams.extend(each)
    
t1 = Counter(all_bigrams).most_common(25)
x1 = [a[0] for a in t1]  # Bigramas
y1 = [a[1] for a in t1]  # Frecuencias

# --- Procesamiento de Trigramas (Tres palabras consecutivas) ---
all_trigrams = []
for each in april18_df['trigrams']:
    all_trigrams.extend(each)
    
t2 = Counter(all_trigrams).most_common(25)
x2 = [a[0] for a in t2]  # Trigramas
y2 = [a[1] for a in t2]  # Frecuencias

# ==========================================
# Visualización de los resultados
# ==========================================
sns.set_style("dark")
fig, axes = plt.subplots(nrows=1, ncols=5, squeeze=True, figsize=(15, 10))

# Gráfica de Unigramas
bar = sns.barplot(y=x, x=y, ax=axes[0], palette='GnBu_d', edgecolor="white")
bar.set(xlabel='', xticks=[])
axes[0].set_title("Principales palabras clave utilizadas por los maestros", fontsize=12)

# Eliminar ejes vacíos para mejor espaciado
fig.delaxes(axes[1])

# Gráfica de Bigramas
bar1 = sns.barplot(y=x1, x=y1, ax=axes[2], palette='GnBu_d', edgecolor="white")
bar1.set(xlabel='', xticks=[])
axes[2].set_title("Principales bigramas utilizados por los maestros", fontsize=12)

# Eliminar ejes vacíos para mejor espaciado
fig.delaxes(axes[3])

# Gráfica de Trigramas
bar2 = sns.barplot(y=x2, x=y2, ax=axes[4], palette='GnBu_d', edgecolor="white")
bar2.set(xlabel='', xticks=[])
axes[4].set_title("Principales trigramas utilizados por los maestros", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# > Las palabras clave más utilizadas en todos los ensayos, en todos los estados y en todos los tipos de escuelas son <b>"escuela", "aprendizaje", "aula", "lectura"</b>. Mientras que los bigramas se centran principalmente en <b>"asientos flexibles"</b> y <b>"idioma inglés"</b>. Un gran número de ensayos de los maestros tratan sobre <b>"desayuno y almuerzo gratuitos"</b>, <b>"aprendizaje del idioma inglés"</b> y "<b>los diversos desafíos enfrentados</b>".
#
# ## <a id="8.2.2"> 8.2.2 ¿Cómo varían las frases principales utilizadas según el Estado? </a>

# %%
# ==========================================
# SECCIÓN 8.2.2: Variación de frases principales por Estado
# ==========================================

# Palabras/frases a ignorar (se mantienen en inglés porque el texto analizado está en inglés)
ignores = ['every day', 'come school']

# ==========================================
# GRÁFICA 1: California, Georgia, Florida
# ==========================================

# --- California (Unigramas) ---
# CORRECCIÓN: Ahora sí extrae de la columna 'unigrams'
all_unigrams = []
for each in april18_df[april18_df['Estado de la Escuela'] == 'California']['unigrams']:
    all_unigrams.extend([x for x in each if x not in ignores])
t = Counter(all_unigrams).most_common(15)
x = [a[0] for a in t]
y = [a[1] for a in t]

# --- Georgia (Bigramas) ---
# CORRECCIÓN: Ahora sí extrae de la columna 'bigrams'
all_bigrams = []
for each in april18_df[april18_df['Estado de la Escuela'] == 'Georgia']['bigrams']:
    all_bigrams.extend([x for x in each if x not in ignores])
t1 = Counter(all_bigrams).most_common(15)
x1 = [a[0] for a in t1]
y1 = [a[1] for a in t1]

# --- Florida (Trigramas) ---
all_trigrams = []
for each in april18_df[april18_df['Estado de la Escuela'] == 'Florida']['trigrams']:
    all_trigrams.extend([x for x in each if x not in ignores])
t2 = Counter(all_trigrams).most_common(15)
x2 = [a[0] for a in t2]
y2 = [a[1] for a in t2]

# Visualización Gráfica 1
sns.set_style("dark")
fig, axes = plt.subplots(nrows=1, ncols=5, squeeze=True, figsize=(15, 6)) # Ancho aumentado para textos en español

bar_uni = sns.barplot(y=x, x=y, ax=axes[0], palette='GnBu_d', edgecolor="white")
bar_uni.set(xlabel='', xticks=[])
axes[0].set_title("Frases más usadas - California (Unigramas)", fontsize=11)

fig.delaxes(axes[1]) # Espacio vacío para separación visual

bar_bi = sns.barplot(y=x1, x=y1, ax=axes[2], palette='GnBu_d', edgecolor="white")
bar_bi.set(xlabel='', xticks=[])
axes[2].set_title("Frases más usadas - Georgia (Bigramas)", fontsize=11)

fig.delaxes(axes[3]) # Espacio vacío para separación visual

bar_tri = sns.barplot(y=x2, x=y2, ax=axes[4], palette='GnBu_d', edgecolor="white")
bar_tri.set(xlabel='', xticks=[])
axes[4].set_title("Frases más usadas - Florida (Trigramas)", fontsize=11)

plt.tight_layout()
plt.show()


# ==========================================
# GRÁFICA 2: Iowa, New York, Texas
# ==========================================

# --- Iowa (Unigramas) ---
all_unigrams = []
for each in april18_df[april18_df['Estado de la Escuela'] == 'Iowa']['unigrams']:
    all_unigrams.extend([x for x in each if x not in ignores])
t = Counter(all_unigrams).most_common(15)
x = [a[0] for a in t]
y = [a[1] for a in t]

# --- New York (Bigramas) ---
all_bigrams = []
for each in april18_df[april18_df['Estado de la Escuela'] == 'New York']['bigrams']:
    all_bigrams.extend([x for x in each if x not in ignores])
t1 = Counter(all_bigrams).most_common(15)
x1 = [a[0] for a in t1]
y1 = [a[1] for a in t1]

# --- Texas (Trigramas) ---
all_trigrams = []
for each in april18_df[april18_df['Estado de la Escuela'] == 'Texas']['trigrams']:
    all_trigrams.extend([x for x in each if x not in ignores])
t2 = Counter(all_trigrams).most_common(15)
x2 = [a[0] for a in t2]
y2 = [a[1] for a in t2]

# Visualización Gráfica 2
sns.set_style("dark")
fig, axes = plt.subplots(nrows=1, ncols=5, squeeze=True, figsize=(15, 6))

bar_uni = sns.barplot(y=x, x=y, ax=axes[0], palette='GnBu_d', edgecolor="white")
bar_uni.set(xlabel='', xticks=[])
axes[0].set_title("Frases más usadas - Iowa (Unigramas)", fontsize=11)

fig.delaxes(axes[1])

bar_bi = sns.barplot(y=x1, x=y1, ax=axes[2], palette='GnBu_d', edgecolor="white")
bar_bi.set(xlabel='', xticks=[])
axes[2].set_title("Frases más usadas - New York (Bigramas)", fontsize=11)

fig.delaxes(axes[3])

bar_tri = sns.barplot(y=x2, x=y2, ax=axes[4], palette='GnBu_d', edgecolor="white")
bar_tri.set(xlabel='', xticks=[])
axes[4].set_title("Frases más usadas - Texas (Trigramas)", fontsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# > - El enfoque principal de los ensayos en los diferentes estados es prácticamente el mismo, aunque se pueden observar algunas diferencias en estados como Texas, donde un gran número de ensayos tratan sobre <b>estudiantes afectados por el huracán Harvey</b>. Los maestros han descrito los "diversos desafíos enfrentados" por los estudiantes, y las <b>"opciones de asientos flexibles"</b> son el enfoque principal de la mayoría de los ensayos.
# > - En Iowa, los maestros han descrito a <b>"estudiantes que provienen de diferentes orígenes"</b> y <b>"diferentes nacionalidades"</b>. En Nueva York, los ensayos también se centran en <b>"maestros de educación especial"</b>, <b>"escuelas de distritos con bajos recursos"</b> y <b>"bajos ingresos"</b>.
# > - En Florida, los maestros han mencionado <b>"precios reducidos para el desayuno y el almuerzo"</b>.
#
# ## <a id="8.2.3"> 8.2.3 "<i>Mis estudiantes son ______ ______ ______</i>": Lo que los maestros describen sobre sus estudiantes </a>

# %%
# ==========================================
# SECCIÓN 8.2.3: "Mis estudiantes son ___ ___ ___"
# Análisis de lo que los maestros describen sobre sus estudiantes
# ==========================================

from textblob import TextBlob, Word
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np

# Cargar la máscara para la nube de palabras (opcional, si tienes la imagen)
# mask = np.array(Image.open('../input/word-cloud-masks/cloud1.png'))

# Lista para almacenar las frases que describen a los estudiantes
mystudents = []

# Buscar en todos los ensayos las frases que comienzan con "my students are"
for x in april18_df['Ensayo del Proyecto']:
    if isinstance(x, str) and x.lower().startswith("my students are"):
        # Extraer las primeras 6 palabras después de "My students are"
        phrase = " ".join(x.replace('My students are', '').split(". ")[0].split("!")[0].strip().split()[:6])
        mystudents.append(phrase)

# Contar las frases más comunes
t3 = Counter(mystudents).most_common(25)
x = [a[0] for a in t3]  # Frases
y = [a[1] for a in t3]  # Frecuencias

# Visualización
sns.set_style("dark")
plt.figure(figsize=(12, 10))
plt.title("Contexto de 'Mis estudiantes son ___ ___ ___'", fontsize=14)

bar = sns.barplot(y=x, x=y, palette="BuGn_r", edgecolor="white")
bar.set(xlabel='', xticks=[])

plt.tight_layout()
plt.show()

# Mostrar estadísticas
print(f"Total de ensayos que comienzan con 'My students are': {len(mystudents)}")
print(f"\nTop 10 frases más comunes:")
for i, (phrase, count) in enumerate(t3[:10], 1):
    print(f"{i}. '{phrase}' - {count} veces")
# Out:
# Total de ensayos que comienzan con 'My students are': 0
#
# Top 10 frases más comunes:

# %% [markdown]
# > - Los maestros utilizaron muchos descriptores para describir a sus estudiantes, por ejemplo: <b>"maravillosos", "geniales", "increíbles", "creativos"</b>. Mientras que en algunos ensayos, los maestros describen a sus estudiantes como <b>"muy especiales para ellos" y "extraordinarios"</b>.
#
# ## <a id="8.2.4"> 8.2.4 Según lo descrito por los maestros, ¿Qué necesitan los estudiantes ______ ______ ______? </a>

# %%
# ==========================================
# SECCIÓN 8.2.4: ¿Qué necesitan los estudiantes?
# Análisis de las declaraciones de necesidad
# ==========================================

mystudents = []

# Buscar en la columna de necesidades limpias las frases que comienzan con "need"
for x in april18_df['clean_need']:
    # Agregamos isinstance para evitar errores con valores nulos (NaN)
    if isinstance(x, str) and x.lower().strip().startswith("need"):
        # Extraer las primeras 3 palabras después de "need"
        phrase = " ".join(x.lower().strip().replace('need', '').split(". ")[0].split("!")[0].strip().split()[:3])
        mystudents.append(phrase)

# Contar las frases más comunes
t3 = Counter(mystudents).most_common(25)
x = [a[0] for a in t3]  # Frases
y = [a[1] for a in t3]  # Frecuencias

# Visualización
sns.set_style("dark")
plt.figure(figsize=(12, 10))
plt.title("Contenido de 'Lo que los estudiantes necesitan'", fontsize=14)

bar = sns.barplot(y=x, x=y, palette="BuGn_r", edgecolor="white")
bar.set(xlabel='', xticks=[])

plt.tight_layout()
plt.show()

# Mostrar estadísticas en la consola
print(f"Total de declaraciones que comienzan con 'need': {len(mystudents)}")
print(f"\nTop 10 frases más comunes sobre lo que necesitan:")
for i, (phrase, count) in enumerate(t3[:10], 1):
    print(f"{i}. '{phrase}' - {count} veces")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clean_need'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 9
#       6 mystudents = []
# ...

# %% [markdown]
# > - Aparte de la principal necesidad sugerida por los maestros, es decir, las <b>"opciones de asientos flexibles"</b>. Otras de las principales necesidades son los <b>"robots de codificación"</b> y los <b>"suministros escolares básicos"</b>. En cuanto a los asientos flexibles, se solicitan principalmente <b>"sillas oscilantes y asientos de pelota de equilibrio"</b>. Otras necesidades relacionadas con la tecnología incluyen <b>"tabletas Amazon Fire"</b>, <b>"juegos de auriculares"</b> y <b>"Osmo Genius Kit"</b>.
#
# ## <a href="8.2.5"> 8.2.5 Título del Proyecto: Palabras principales utilizadas </a>

# %%
# ==========================================
# SECCIÓN 8.2.5: Nube de palabras con silueta de niña leyendo (OPTIMIZADA)
# ==========================================

from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen de silueta
imagen = Image.open('leyendo.png')

# Convertir a escala de grises
mask = np.array(imagen.convert('L'))

# Unir todos los títulos de proyectos
titulo_col = 'Título del Proyecto' if 'Título del Proyecto' in april18_df.columns else 'Project Title'
text = " ".join(april18_df[titulo_col].dropna()).lower()

# Eliminar palabras de ruido
for w in ['need', 'student', 'classroom']:
    text = text.replace(w, " ")

# Generar la nube de palabras CON PARÁMETROS OPTIMIZADOS
wc = WordCloud(
    width=400,              # Ancho que coincide con la proporción de la imagen
    height=800,             # Alto (la silueta es vertical)
    max_words=1200,          # Reducido para que no se dispersen tanto
    stopwords=STOPWORDS, 
    colormap='cool', 
    background_color='white', 
    mask=mask,
    contour_width=0,
    mode='RGB',
    min_font_size=4,        # Tamaño mínimo más pequeño
    max_font_size=150,      # Tamaño máximo ajustado
    prefer_horizontal=0.6,  # 60% horizontales, 40% verticales
    relative_scaling=0.3,   # Mejor distribución de tamaños
    scale=2,                # Mayor resolución
    random_state=42         # Reproducibilidad
).generate(text)

# Visualización
plt.figure(figsize=(8, 12))  # Proporción vertical
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('Palabras más frecuentes en los Títulos de los Proyectos', fontsize=14, pad=20)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[108], line 11
#       8 import matplotlib.pyplot as plt
#      10 # Cargar la imagen de silueta
# ---> 11 imagen = Image.open('leyendo.png')
#      13 # Convertir a escala de grises
#      14 mask = np.array(imagen.convert('L'))
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'leyendo.png'

# %% [markdown]
# > Temas como los **asientos flexibles**, las **Chromebooks**, la **lectura**, el **aprendizaje**, la **tecnología** y los **libros** son el enfoque principal de un gran número de maestros para sus estudiantes.

# %% [markdown]
# ## <a href="9"> 9. Análisis y Comparación de las Características Clave de los Proyectos </a>
#
# ## <a href="9.1"> 9.1 Proyectos Expirados vs Proyectos Financiados </a>
#
# En esta sección, exploremos y comprendamos las características clave de los proyectos que fueron financiados con éxito y comparémoslos con los proyectos que expiraron. Me centraré en los proyectos del año pasado, es decir, 2017.

# %%
# ==========================================
# SECCIÓN 9.1: Proyectos Expirados vs Proyectos Financiados (2017)
# ==========================================

import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# ==========================================
# PASO 1: Filtrar proyectos de 2017
# IMPORTANTE: Los valores de estado están en INGLÉS
# ==========================================
expirados = projects_df[(projects_df['Año de Publicación'] == 2017) & 
                        (projects_df['Estado Actual del Proyecto'] == 'Expired')].copy()

financiados = projects_df[(projects_df['Año de Publicación'] == 2017) & 
                          (projects_df['Estado Actual del Proyecto'] == 'Fully Funded')].copy()

print(f"✅ Proyectos Expirados (2017): {len(expirados)}")
print(f"✅ Proyectos Financiados (2017): {len(financiados)}")

# ==========================================
# PASO 1.5: Renombrar columna en teachers_df para que coincida
# (La columna original en inglés es 'Teacher ID')
# ==========================================
teachers_df = teachers_df.rename(columns={'Teacher ID': 'ID de Maestro'})

# ==========================================
# PASO 2: Unir con la tabla de maestros
# ==========================================
expirados = expirados.merge(teachers_df, on="ID de Maestro", how='left')
financiados = financiados.merge(teachers_df, on="ID de Maestro", how='left')

# ==========================================
# PASO 3: Función auxiliar para generar trazas
# ==========================================
def obtener_traza(col, func, flag=None, leg=False):
    t1 = expirados[col].value_counts()
    t2 = financiados[col].value_counts()

    if flag == 'num':
        t1 = expirados[expirados['NumProjects'] <= 20][col].value_counts()    
        t2 = financiados[financiados['NumProjects'] <= 20][col].value_counts() 
    
    trace1 = func(
        x=t1.index,
        y=[float(a)*100/sum(t1.values) for a in t1.values],
        name='Expirado',
        marker=dict(color='#e82041'),
        showlegend=leg,
        opacity=0.9
    )
    trace2 = func(
        x=t2.index,
        y=[float(a)*100/sum(t2.values) for a in t2.values],
        name='Financiado',
        marker=dict(color='#0de286'),
        opacity=0.9, 
        showlegend=leg
    )
    return trace1, trace2

# ==========================================
# PASO 4: Generar trazas
# ==========================================
tr1, tr2 = obtener_traza('Categoría de Nivel de Grado del Proyecto', go.Scatter)
tr3, tr4 = obtener_traza('Tipo de Zona Metropolitana', go.Scatter)
tr7, tr8 = obtener_traza('Categoría de Recursos del Proyecto', go.Bar)
tr9, tr10 = obtener_traza('Mes de Publicación', go.Bar, leg=True)

# ==========================================
# PASO 5: Análisis de Cantidad de Palabras en el Ensayo
# ==========================================
expirados['conteo_palabras'] = expirados['Ensayo del Proyecto'].apply(lambda x: len(str(x).split()))
financiados['conteo_palabras'] = financiados['Ensayo del Proyecto'].apply(lambda x: len(str(x).split()))

bins_wc = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 10000]

# Expirados
expirados['wc_bin'] = pd.cut(expirados['conteo_palabras'], bins_wc)
t1_wc = dict(expirados['wc_bin'].value_counts())
labels1 = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1_wc.keys()]
vals1 = [float(a)*100/sum(t1_wc.values()) for a in list(t1_wc.values())]
d1 = {labels1[i]: vals1[i] for i in range(len(labels1))}
order_wc = ['0-50', '50-100', '100-150', '150-200', '200-250', '250-300', '300-350', '350-400', '400-450', '450-500', '500-10000']
values1 = [d1.get(v, 0) for v in order_wc]

tr13 = go.Bar(x=order_wc, y=values1, name='Expirado', marker=dict(color='#e82041'), opacity=0.9)

# Financiados
financiados['wc_bin'] = pd.cut(financiados['conteo_palabras'], bins_wc)
t2_wc = dict(financiados['wc_bin'].value_counts())
labels2 = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t2_wc.keys()]
vals2 = [float(a)*100/sum(t2_wc.values()) for a in list(t2_wc.values())]
d2 = {labels2[i]: vals2[i] for i in range(len(labels2))}
values2 = [d2.get(v, 0) for v in order_wc]

tr14 = go.Bar(x=order_wc, y=values2, name='Financiado', marker=dict(color='#0de286'), opacity=0.9)

# ==========================================
# PASO 6: Análisis de Costo del Proyecto
# Usamos la columna 'costo' que ya existe y está limpia
# ==========================================
bins_cost = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 70000]
order_cost = ['100-500', '500-1000', '1000-1500', '1500-2000', '2000-2500', '2500-3000', '3000-70000']

# Expirados
expirados['costo_bin'] = pd.cut(expirados['costo'], bins_cost)
t1_cost = dict(expirados['costo_bin'].value_counts())
labels1_c = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1_cost.keys()]
vals1_c = [float(a)*100/sum(t1_cost.values()) for a in list(t1_cost.values())]
d1_c = {labels1_c[i]: vals1_c[i] for i in range(len(labels1_c))}
values1_c = [d1_c.get(v, 0) for v in order_cost]

tr15 = go.Scatter(x=order_cost, y=values1_c, name='Expirado', fill='tozeroy', marker=dict(color='#e82041'), opacity=0.9)

# Financiados
financiados['costo_bin'] = pd.cut(financiados['costo'], bins_cost)
t2_cost = dict(financiados['costo_bin'].value_counts())
labels2_c = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t2_cost.keys()]
vals2_c = [float(a)*100/sum(t2_cost.values()) for a in list(t2_cost.values())]
d2_c = {labels2_c[i]: vals2_c[i] for i in range(len(labels2_c))}
values2_c = [d2_c.get(v, 0) for v in order_cost]

tr16 = go.Scatter(x=order_cost, y=values2_c, name='Financiado', fill='tozeroy', marker=dict(color='#0de286'), opacity=0.9)

# ==========================================
# PASO 7: Crear el Dashboard con Subplots
# ==========================================
titulos_graficas = [
    'Categoría de Nivel de Grado', 
    "Tipo de Zona Metropolitana", 
    "Costo del Proyecto (en $)", 
    "Cantidad de Palabras en el Ensayo", 
    "Mes de Publicación", 
    "Categoría de Recursos"
]

fig = make_subplots(
    rows=3, cols=2, 
    subplot_titles=titulos_graficas, 
    specs=[[{}, {}], [{},{}], [{}, {}]]
) 

fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 1)
fig.append_trace(tr3, 1, 2)
fig.append_trace(tr4, 1, 2)

fig.append_trace(tr15, 2, 1) # Costo
fig.append_trace(tr16, 2, 1)

fig.append_trace(tr13, 2, 2) # Palabras
fig.append_trace(tr14, 2, 2)

fig.append_trace(tr9, 3, 1)  # Mes
fig.append_trace(tr10, 3, 1)

fig.append_trace(tr7, 3, 2)  # Recursos
fig.append_trace(tr8, 3, 2)

# Actualizar el diseño general
fig.update_layout(
    barmode='group',
    title={
        'text': 'Comparación de Características Clave: <b>Proyectos Expirados vs Financiados</b>',
        'font': {'size': 22, 'color': '#000'},
        'y': 0.98,
        'x': 0.5,
        'xanchor': 'center'
    },
    margin=dict(t=100, b=100),
    paper_bgcolor='rgb(254, 247, 234)',
    plot_bgcolor='rgb(254, 247, 234)',
    height=1000
)

# Mostrar la figura
fig.show()
# Out:
# ✅ Proyectos Expirados (2017): 0
# ✅ Proyectos Financiados (2017): 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tipo de Zona Metropolitana'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# ==========================================
# SECCIÓN 9.2: Nubes de palabras comparativas (Silueta "Leyendo")
# ==========================================

from wordcloud import WordCloud
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# 1. Unir todos los títulos de proyectos en un solo texto
# Proyectos Expirados (negativos)
neg_text_cln = " ".join(expirados['Título del Proyecto'].dropna())

# Proyectos Financiados (positivos)  
pos_text_cln = " ".join(financiados['Título del Proyecto'].dropna())

# 2. Cargar y preparar la máscara con la silueta de la niña leyendo
imagen = Image.open('leyendo.png')
# Convertir a escala de grises para que WordCloud la interprete correctamente
mask = np.array(imagen.convert('L'))

# 3. Crear figura con dos subgráficas
# Ajustamos el figsize para que quepan bien dos siluetas verticales una al lado de la otra
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[14, 10], facecolor='#fef7ea')

# ==========================================
# Nube de palabras: Proyectos Expirados
# ==========================================
wordcloud1 = WordCloud(
    max_words=1200,
    colormap='magma',  # Colores cálidos/oscuros (rojos/naranjas) para lo negativo
    background_color='rgb(254, 247, 234)', 
    mask=mask,
    contour_width=0,
    min_font_size=5
).generate(neg_text_cln)

ax1.imshow(wordcloud1, interpolation='bilinear')
ax1.axis('off')
ax1.set_title('Palabras principales - Proyectos Expirados', fontsize=14, pad=10, fontweight='bold')

# ==========================================
# Nube de palabras: Proyectos Financiados
# ==========================================
wordcloud2 = WordCloud(
    max_words=1200,
    colormap='nipy_spectral',  # Colores variados y brillantes para lo positivo
    background_color='rgb(254, 247, 234)', 
    mask=mask,
    contour_width=0,
    min_font_size=5
).generate(pos_text_cln)

ax2.imshow(wordcloud2, interpolation='bilinear')
ax2.axis('off')
ax2.set_title('Palabras principales - Proyectos Financiados', fontsize=14, pad=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# > La comparación muestra las siguientes conclusiones:
# >
# > - Los proyectos que pertenecieron al **nivel de grados PreK-2** tienen un porcentaje más alto de proyectos exitosos que de proyectos expirados. Mientras que todos los demás grados tienen un porcentaje más alto de proyectos expirados que de proyectos financiados exitosamente. Quizás los donantes prefieren **donar a niños de grados inferiores** más que a los de grados superiores.
# >
# > - Los proyectos financiados exitosamente tienen un porcentaje más alto para escuelas ubicadas en **áreas urbanas**, mientras que los proyectos expirados tienen un porcentaje más alto de proyectos en escuelas ubicadas en **áreas rurales, suburbanas o pueblos**.
# >
# > - Otra característica de los proyectos financiados está relacionada con el costo del proyecto. Los proyectos cuyo costo total es menor a USD 500 tienen un porcentaje muy alto de proyectos financiados exitosamente, mientras que lo contrario también es cierto: un alto porcentaje de proyectos que expiraron tienen costos más altos, es decir, mayores a USD 500.
# >
# > - Los ensayos de los proyectos son una parte esencial de los proyectos de DonorsChoose, y el número de palabras utilizadas en el texto juega un buen papel en el resultado del proyecto. Como se ve en la cuarta gráfica, los proyectos que fueron financiados exitosamente son más comunes para proyectos con **más de 250 palabras en el ensayo**. Esto indica que se debería animar a los maestros a escribir de manera más exhaustiva sobre los proyectos.
# >
# > - Un número significativo de proyectos que se publicaron en el cuarto trimestre del año calendario, es decir, entre **octubre y diciembre**, fueron financiados exitosamente en su mayoría. Esto indica un buen período de tiempo cuando los donantes tienden a donar más. Quizás los maestros que sienten que no están recibiendo donaciones para sus proyectos podrían comenzar a publicarlos en los meses de noviembre o diciembre. Todos los demás meses del año tienen un porcentaje más alto de proyectos expirados que de proyectos financiados.
# >
# > - Se observa una conclusión interesante entre los proyectos que expiraron: un gran porcentaje de tales proyectos tenía un alto costo de requisitos técnicos como **iPads, Chromebooks**, etc. Las categorías de recursos **suministros y tecnologías** tienen un número muy alto de proyectos expirados.
# >
# > - En todos los Estados Unidos, hay pocos estados en los que el porcentaje de proyectos financiados es mayor que el porcentaje de proyectos expirados. Algunos de estos estados son: **Illinois, Massachusetts, Oklahoma**. El porcentaje de proyectos expirados es más alto en otros estados. Quizás DonorsChoose podría aumentar las campañas de marketing y correo electrónico para atraer donantes de estos estados.
# >
# > - Un porcentaje más alto de proyectos financiados solicitó **asientos flexibles y materiales de lectura**, mientras que los proyectos expirados tenían un alto porcentaje de **artículos relacionados con tecnología**.
#
# ## <a href="9.2"> 9.2 Proyectos con Duración de Financiación Baja vs Alta </a>
#
# Ahora comparemos las características de los proyectos que fueron financiados exitosamente en un período más corto, es decir, menos de 1 día, versus los proyectos que tardaron más de 2 meses en ser financiados.

# %%
# ==========================================
# SECCIÓN 9.2: Proyectos con Duración de Financiación Corta vs Larga
# ==========================================

import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# ==========================================
# PASO 1: Preparar columna de tiempo de financiación
# ==========================================
# La columna 'Tiempo de Financiamiento' contiene valores como "X days" o "NaT"
# Extraemos solo el número de días
projects_df['tiempo_dias'] = projects_df['Tiempo de Financiamiento'].apply(
    lambda x: str(x).split()[0] if pd.notna(x) else 'NaT'
)

# Filtrar proyectos con tiempo válido y convertir a entero
tempdf = projects_df[projects_df['tiempo_dias'] != "NaT"].copy()
tempdf['tiempo_dias'] = tempdf['tiempo_dias'].apply(int)

# Filtrar solo proyectos de 2017
tempdf = tempdf[tempdf['Año de Publicación'] == 2017]

print(f"Total proyectos de 2017 con tiempo de financiación válido: {len(tempdf)}")

# ==========================================
# PASO 2: Crear dos grupos de comparación
# ==========================================
# df1: Financiación rápida (≤ 1 día)
df1 = tempdf[tempdf['tiempo_dias'] <= 1].copy()

# df2: Financiación lenta (≥ 60 días)
df2 = tempdf[tempdf['tiempo_dias'] >= 60].copy()

print(f"Proyectos con financiación ≤ 1 día: {len(df1)}")
print(f"Proyectos con financiación ≥ 60 días: {len(df2)}")

# ==========================================
# PASO 3: Unir con tabla de maestros
# ==========================================
df1 = df1.merge(teachers_df, on="ID de Maestro", how='left')
df2 = df2.merge(teachers_df, on="ID de Maestro", how='left')


# ==========================================
# PASO 4: Función auxiliar para generar trazas
# ==========================================
def obtener_traza(col, func, flag=None, leg=False):
    t1 = df1[col].value_counts()
    t2 = df2[col].value_counts()

    if flag == 'num':
        t1 = df1[df1['NumProjects'] <= 20][col].value_counts()    
        t2 = df2[df2['NumProjects'] <= 20][col].value_counts() 
    
    trace1 = func(
        x=t1.index,
        y=[float(a)*100/sum(t1.values) for a in t1.values],
        name='Financiación Rápida (≤1 día)',
        marker=dict(color='#0de286'),
        showlegend=leg,
        opacity=0.9
    )
    trace2 = func(
        x=t2.index,
        y=[float(a)*100/sum(t2.values) for a in t2.values],
        name='Financiación Lenta (≥60 días)',
        marker=dict(color='#e82041'),
        opacity=0.9, 
        showlegend=leg
    )
    return trace1, trace2


# ==========================================
# PASO 5: Generar trazas para las diferentes categorías
# ==========================================
tr1, tr2 = obtener_traza('Categoría de Nivel de Grado del Proyecto', go.Scatter)
tr3, tr4 = obtener_traza('Tipo de Zona Metropolitana', go.Scatter)
tr7, tr8 = obtener_traza('Categoría de Recursos del Proyecto', go.Bar)
tr9, tr10 = obtener_traza('Mes de Publicación', go.Bar, leg=True)


# ==========================================
# PASO 6: Análisis de Cantidad de Palabras en el Ensayo
# ==========================================
df1['conteo_palabras'] = df1['Ensayo del Proyecto'].apply(lambda x: len(str(x).split()))
df2['conteo_palabras'] = df2['Ensayo del Proyecto'].apply(lambda x: len(str(x).split()))

bins_wc = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 10000]

# Financiación rápida
df1['wc_bin'] = pd.cut(df1['conteo_palabras'], bins_wc)
t1_wc = dict(df1['wc_bin'].value_counts())
labels1 = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1_wc.keys()]
vals1 = [float(a)*100/sum(t1_wc.values()) for a in list(t1_wc.values())]
d1 = {labels1[i]: vals1[i] for i in range(len(labels1))}
order_wc = ['0-50', '50-100', '100-150', '150-200', '200-250', '250-300', '300-350', '350-400', '400-450', '450-500', '500-10000']
values1 = [d1.get(v, 0) for v in order_wc]

tr13 = go.Bar(x=order_wc, y=values1, name='Financiación Rápida (≤1 día)', 
              marker=dict(color='#0de286'), showlegend=False, opacity=0.9)

# Financiación lenta (CORREGIDO: usa t2_wc en lugar de t1_wc)
df2['wc_bin'] = pd.cut(df2['conteo_palabras'], bins_wc)
t2_wc = dict(df2['wc_bin'].value_counts())
labels2 = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t2_wc.keys()]
vals2 = [float(a)*100/sum(t2_wc.values()) for a in list(t2_wc.values())]
d2 = {labels2[i]: vals2[i] for i in range(len(labels2))}
values2 = [d2.get(v, 0) for v in order_wc]

tr14 = go.Bar(x=order_wc, y=values2, name='Financiación Lenta (≥60 días)', 
              marker=dict(color='#e82041'), showlegend=False, opacity=0.9)


# ==========================================
# PASO 7: Análisis de Costo del Proyecto
# ==========================================
bins_cost = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 70000]
order_cost = ['100-500', '500-1000', '1000-1500', '1500-2000', '2000-2500', '2500-3000', '3000-70000']

# Financiación rápida
df1['costo_bin'] = pd.cut(df1['costo'], bins_cost)
t1_cost = dict(df1['costo_bin'].value_counts())
labels1_c = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1_cost.keys()]
vals1_c = [float(a)*100/sum(t1_cost.values()) for a in list(t1_cost.values())]
d1_c = {labels1_c[i]: vals1_c[i] for i in range(len(labels1_c))}
values1_c = [d1_c.get(v, 0) for v in order_cost]

tr15 = go.Scatter(x=order_cost, y=values1_c, name='Financiación Rápida (≤1 día)', 
                  fill='tozeroy', marker=dict(color='#0de286'), showlegend=False, opacity=0.9)

# Financiación lenta (CORREGIDO: usa t2_cost en lugar de t1_cost)
df2['costo_bin'] = pd.cut(df2['costo'], bins_cost)
t2_cost = dict(df2['costo_bin'].value_counts())
labels2_c = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t2_cost.keys()]
vals2_c = [float(a)*100/sum(t2_cost.values()) for a in list(t2_cost.values())]
d2_c = {labels2_c[i]: vals2_c[i] for i in range(len(labels2_c))}
values2_c = [d2_c.get(v, 0) for v in order_cost]

tr16 = go.Scatter(x=order_cost, y=values2_c, name='Financiación Lenta (≥60 días)', 
                  fill='tozeroy', marker=dict(color='#e82041'), showlegend=False, opacity=0.9)


# ==========================================
# PASO 8: Crear el Dashboard con Subplots
# ==========================================
titulos_graficas = [
    'Categoría de Nivel de Grado', 
    "Tipo de Zona Metropolitana", 
    "Costo del Proyecto (en $)", 
    "Cantidad de Palabras en el Ensayo", 
    "Mes de Publicación", 
    "Categoría de Recursos"
]

fig = make_subplots(
    rows=3, cols=2, 
    subplot_titles=titulos_graficas, 
    specs=[[{}, {}], [{},{}], [{}, {}]]
) 

# Agregar trazas a las subgráficas (Fila, Columna)
fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 1)
fig.append_trace(tr3, 1, 2)
fig.append_trace(tr4, 1, 2)

fig.append_trace(tr15, 2, 1) # Costo
fig.append_trace(tr16, 2, 1)

fig.append_trace(tr13, 2, 2) # Palabras
fig.append_trace(tr14, 2, 2)

fig.append_trace(tr9, 3, 1)  # Mes
fig.append_trace(tr10, 3, 1)

fig.append_trace(tr7, 3, 2)  # Recursos
fig.append_trace(tr8, 3, 2)

# Actualizar el diseño general
fig.update_layout(
    barmode='group',
    title={
        'text': 'Comparación de Características Clave: <b>Proyectos con Financiación Rápida vs Lenta</b>',
        'font': {'size': 22, 'color': '#000'},
        'y': 0.98,
        'x': 0.5,
        'xanchor': 'center'
    },
    legend=dict(x=0.25, y=1.06, orientation="h"),
    margin=dict(t=100, b=100),
    paper_bgcolor='rgb(254, 247, 234)',
    plot_bgcolor='rgb(254, 247, 234)',
    height=1000
)

# Mostrar la figura
fig.show()
# Out:
# Total proyectos de 2017 con tiempo de financiación válido: 0
# Proyectos con financiación ≤ 1 día: 0
# Proyectos con financiación ≥ 60 días: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tipo de Zona Metropolitana'
#
# ...

# %%
# ==========================================
# SECCIÓN 9.3: Nubes de palabras comparativas - Tiempo de Financiación
# (Usando silueta "Leyendo")
# ==========================================

from wordcloud import WordCloud
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# 1. Unir todos los títulos de proyectos en un solo texto
# Proyectos con financiación lenta (≥60 días)
pos_text_cln = " ".join(df2['Título del Proyecto'].dropna())

# Proyectos con financiación rápida (≤1 día)
neg_text_cln = " ".join(df1['Título del Proyecto'].dropna())

# 2. Eliminar palabras de ruido (se mantienen en inglés porque los títulos están en inglés)
noise = ['Learning', 'Student', 'Classroom']
for n in noise:
    pos_text_cln = pos_text_cln.replace(n, " ")
    neg_text_cln = neg_text_cln.replace(n, " ")

# 3. Cargar y preparar la máscara con la silueta de la niña leyendo
imagen = Image.open('leyendo.png')
# Convertir a escala de grises para que WordCloud la interprete correctamente
mask = np.array(imagen.convert('L'))

# 4. Crear figura con dos subgráficas
# Ajustamos el figsize para que quepan bien dos siluetas verticales
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[14, 10], facecolor='#fef7ea')

# ==========================================
# Nube de palabras: Proyectos con Financiación Rápida (≤1 día)
# ==========================================
wordcloud1 = WordCloud(
    max_words=1200,
    colormap='magma',  # Colores cálidos/oscuros
    background_color='rgb(254, 247, 234)', 
    mask=mask,
    contour_width=0,
    min_font_size=5
).generate(neg_text_cln)

ax1.imshow(wordcloud1, interpolation='bilinear')
ax1.axis('off')
ax1.set_title('Palabras principales - Financiación Rápida (≤1 día)', fontsize=14, pad=10, fontweight='bold')

# ==========================================
# Nube de palabras: Proyectos con Financiación Lenta (≥60 días)
# ==========================================
wordcloud2 = WordCloud(
    max_words=1200,
    colormap='nipy_spectral',  # Colores variados y brillantes
    background_color='rgb(254, 247, 234)', 
    mask=mask,
    contour_width=0,
    min_font_size=5
).generate(pos_text_cln)

ax2.imshow(wordcloud2, interpolation='bilinear')
ax2.axis('off')
ax2.set_title('Palabras principales - Financiación Lenta (≥60 días)', fontsize=14, pad=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# > La comparación muestra las siguientes conclusiones:
# >
# > - Podemos ver que los proyectos que fueron financiados exitosamente en un día o menos a menudo pertenecen a los **niveles de grados 6-12**, mientras que un porcentaje más alto de proyectos que tardaron más tiempo en completar las donaciones pertenecen a grados inferiores.
# >
# > - Las **áreas suburbanas** tuvieron un mayor porcentaje de proyectos completados en períodos de tiempo más cortos en comparación con cualquier otro tipo de área escolar.
# >
# > - Se espera que los proyectos con un costo total menor, es decir, menos de 500 USD, tengan mayores posibilidades de completarse/financiarse en muy poco tiempo, en comparación con los proyectos que requieren cantidades más altas. Lo mismo se observa en las gráficas.
# >
# > - En los proyectos que se financiaron en menos de un día, los maestros utilizaron un **número relativamente mayor de palabras**, es decir, más de 250 en sus ensayos. Para los proyectos con ensayos de menos de 500 palabras, se observó una mayor cantidad de proyectos que tardaron más tiempo en financiarse.
# >
# > - Un mayor número de proyectos publicados en los meses de **febrero, marzo, agosto y octubre** fueron financiados exitosamente en un período de tiempo más corto, mientras que el porcentaje más alto de proyectos financiados en un tiempo más largo se observó en los meses de diciembre y septiembre.
#
# ## <a href="9.3"> 9.3 Proyectos con Donantes Únicos vs Múltiples Donantes </a>
#
# Comparemos las características de los proyectos en los que donó un solo donante frente a aquellos en los que donaron más de diez donantes.

# %%
# ==========================================
# SECCIÓN 9.3: Proyectos con Donante Único vs Múltiples Donantes (AJUSTADO)
# ==========================================

import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# ==========================================
# PASO 0: Renombrar columnas de donations_df (si no se hizo antes)
# ==========================================
donations_df = donations_df.rename(columns={
    'Donation ID': 'ID de Donación',
    'Donation Included Optional Donation': 'Incluyó Donación Opcional',
    'Donation Amount': 'Monto de Donación',
    'Donor Cart Sequence': 'Secuencia de Carrito del Donante',
    'Donation Received Date': 'Fecha de Recepción de Donación',
    'Project ID': 'ID de Proyecto',
    'Donor ID': 'ID de Donante'
})

# ==========================================
# PASO 1: Calcular número de donaciones por proyecto
# ==========================================
num_donaciones = donations_df.groupby('ID de Proyecto').agg({'ID de Donación': 'count'}).reset_index()
num_donaciones = num_donaciones.rename(columns={'ID de Donación': 'NumDonaciones'})

tempdf = projects_df.merge(num_donaciones, on="ID de Proyecto", how='left')
tempdf['NumDonaciones'] = tempdf['NumDonaciones'].fillna(0).astype(int)

# ==========================================
# PASO 2: Filtrar proyectos de 2017
# AJUSTE CLAVE: Usar >= 2 para "Múltiples Donantes" porque no hay datos con >10
# ==========================================
df1 = tempdf[(tempdf['Año de Publicación'] == 2017) & (tempdf['NumDonaciones'] == 1)].copy()
df2 = tempdf[(tempdf['Año de Publicación'] == 2017) & (tempdf['NumDonaciones'] >= 2)].copy()

print(f"✅ Proyectos con 1 donante (2017): {len(df1)}")
print(f"✅ Proyectos con 2 o más donantes (2017): {len(df2)}")

# ==========================================
# PASO 3: Unir con tabla de maestros
# ==========================================
df1 = df1.merge(teachers_df, on="ID de Maestro", how='left')
df2 = df2.merge(teachers_df, on="ID de Maestro", how='left')


# ==========================================
# PASO 4: Función auxiliar para generar trazas
# ==========================================
def obtener_traza(col, func, flag=None, leg=False):
    t1 = df1[col].value_counts()
    t2 = df2[col].value_counts()

    if flag == 'num':
        t1 = df1[df1['NumProjects'] <= 20][col].value_counts()    
        t2 = df2[df2['NumProjects'] <= 20][col].value_counts() 
    
    trace1 = func(
        x=t1.index,
        y=[float(a)*100/sum(t1.values) for a in t1.values],
        name='Donante Único',
        marker=dict(color='#0de286'),
        showlegend=leg,
        opacity=0.9
    )
    trace2 = func(
        x=t2.index,
        y=[float(a)*100/sum(t2.values) for a in t2.values],
        name='Múltiples Donantes',
        marker=dict(color='#e82041'),
        opacity=0.9, 
        showlegend=leg
    )
    return trace1, trace2


# ==========================================
# PASO 5: Generar trazas
# ==========================================
tr1, tr2 = obtener_traza('Categoría de Nivel de Grado del Proyecto', go.Scatter)
tr3, tr4 = obtener_traza('Tipo de Zona Metropolitana', go.Scatter)
tr7, tr8 = obtener_traza('Categoría de Recursos del Proyecto', go.Bar)
tr9, tr10 = obtener_traza('Mes de Publicación', go.Bar, leg=True)


# ==========================================
# PASO 6: Análisis de Cantidad de Palabras
# ==========================================
df1['conteo_palabras'] = df1['Ensayo del Proyecto'].apply(lambda x: len(str(x).split()))
df2['conteo_palabras'] = df2['Ensayo del Proyecto'].apply(lambda x: len(str(x).split()))

bins_wc = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 10000]
order_wc = ['0-50', '50-100', '100-150', '150-200', '200-250', '250-300', '300-350', '350-400', '400-450', '450-500', '500-10000']

# Donante único
df1['wc_bin'] = pd.cut(df1['conteo_palabras'], bins_wc)
t1_wc = dict(df1['wc_bin'].value_counts())
d1 = {str(b).replace("]","").replace("(","").replace(", ","-"): float(a)*100/sum(t1_wc.values()) for a, b in zip(t1_wc.values(), t1_wc.keys())}
values1 = [d1.get(v, 0) for v in order_wc]
tr13 = go.Bar(x=order_wc, y=values1, name='Donante Único', marker=dict(color='#0de286'), showlegend=False, opacity=0.9)

# Múltiples donantes
df2['wc_bin'] = pd.cut(df2['conteo_palabras'], bins_wc)
t2_wc = dict(df2['wc_bin'].value_counts())
d2 = {str(b).replace("]","").replace("(","").replace(", ","-"): float(a)*100/sum(t2_wc.values()) for a, b in zip(t2_wc.values(), t2_wc.keys())}
values2 = [d2.get(v, 0) for v in order_wc]
tr14 = go.Bar(x=order_wc, y=values2, name='Múltiples Donantes', marker=dict(color='#e82041'), showlegend=False, opacity=0.9)


# ==========================================
# PASO 7: Análisis de Costo
# ==========================================
bins_cost = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 70000]
order_cost = ['100-500', '500-1000', '1000-1500', '1500-2000', '2000-2500', '2500-3000', '3000-70000']

# Donante único
df1['costo_bin'] = pd.cut(df1['costo'], bins_cost)
t1_cost = dict(df1['costo_bin'].value_counts())
d1_c = {str(b).replace("]","").replace("(","").replace(", ","-"): float(a)*100/sum(t1_cost.values()) for a, b in zip(t1_cost.values(), t1_cost.keys())}
values1_c = [d1_c.get(v, 0) for v in order_cost]
tr15 = go.Scatter(x=order_cost, y=values1_c, name='Donante Único', fill='tozeroy', marker=dict(color='#0de286'), showlegend=False, opacity=0.9)

# Múltiples donantes
df2['costo_bin'] = pd.cut(df2['costo'], bins_cost)
t2_cost = dict(df2['costo_bin'].value_counts())
d2_c = {str(b).replace("]","").replace("(","").replace(", ","-"): float(a)*100/sum(t2_cost.values()) for a, b in zip(t2_cost.values(), t2_cost.keys())}
values2_c = [d2_c.get(v, 0) for v in order_cost]
tr16 = go.Scatter(x=order_cost, y=values2_c, name='Múltiples Donantes', fill='tozeroy', marker=dict(color='#e82041'), showlegend=False, opacity=0.9)


# ==========================================
# PASO 8: Crear Dashboard
# ==========================================
titulos_graficas = [
    'Categoría de Nivel de Grado', 
    "Tipo de Zona Metropolitana", 
    "Costo del Proyecto (en $)", 
    "Cantidad de Palabras en el Ensayo", 
    "Mes de Publicación", 
    "Categoría de Recursos"
]

fig = make_subplots(rows=3, cols=2, subplot_titles=titulos_graficas, specs=[[{}, {}], [{},{}], [{}, {}]]) 

fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 1)
fig.append_trace(tr3, 1, 2)
fig.append_trace(tr4, 1, 2)
fig.append_trace(tr15, 2, 1)
fig.append_trace(tr16, 2, 1)
fig.append_trace(tr13, 2, 2)
fig.append_trace(tr14, 2, 2)
fig.append_trace(tr9, 3, 1)
fig.append_trace(tr10, 3, 1)
fig.append_trace(tr7, 3, 2)
fig.append_trace(tr8, 3, 2)

fig.update_layout(
    barmode='group',
    title={
        'text': 'Comparación de Características Clave: <b>Proyectos con Donante Único vs Múltiples Donantes</b>',
        'font': {'size': 22, 'color': '#000'},
        'y': 0.98,
        'x': 0.5,
        'xanchor': 'center'
    },
    legend=dict(x=0.25, y=1.06, orientation="h"),
    margin=dict(t=100, b=100),
    paper_bgcolor='rgb(254, 247, 234)',
    plot_bgcolor='rgb(254, 247, 234)',
    height=1000
)

fig.show()
# Out:
# ✅ Proyectos con 1 donante (2017): 0
# ✅ Proyectos con 2 o más donantes (2017): 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tipo de Zona Metropolitana'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# ==========================================
# SECCIÓN 9.3: Nubes de palabras comparativas - Donantes
# (Usando silueta "Leyendo")
# ==========================================

from wordcloud import WordCloud
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# 1. Unir todos los títulos de proyectos en un solo texto
# Proyectos con Múltiples Donantes (>= 2)
pos_text_cln = " ".join(df2['Título del Proyecto'].dropna())

# Proyectos con Donante Único (1 donante)
neg_text_cln = " ".join(df1['Título del Proyecto'].dropna())

# 2. Eliminar palabras de ruido (se mantienen en inglés porque los títulos están en inglés)
noise = ['Learning', 'Student', 'Classroom', 'Need']
for n in noise:
    pos_text_cln = pos_text_cln.replace(n, " ")
    neg_text_cln = neg_text_cln.replace(n, " ")

# 3. Cargar y preparar la máscara con la silueta de la niña leyendo
imagen = Image.open('leyendo.png')
# Convertir a escala de grises para que WordCloud la interprete correctamente
mask = np.array(imagen.convert('L'))

# 4. Crear figura con dos subgráficas
# Ajustamos el figsize para que quepan bien dos siluetas verticales
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[14, 10], facecolor='#fef7ea')

# ==========================================
# Nube de palabras: Proyectos con Donante Único
# ==========================================
wordcloud1 = WordCloud(
    max_words=1200,
    colormap='magma',  # Colores cálidos/oscuros
    background_color='rgb(254, 247, 234)', 
    mask=mask,
    contour_width=0,
    min_font_size=5
).generate(neg_text_cln)

ax1.imshow(wordcloud1, interpolation='bilinear')
ax1.axis('off')
ax1.set_title('Palabras principales - Donante Único', fontsize=14, pad=10, fontweight='bold')

# ==========================================
# Nube de palabras: Proyectos con Múltiples Donantes
# ==========================================
wordcloud2 = WordCloud(
    max_words=1200,
    colormap='nipy_spectral',  # Colores variados y brillantes
    background_color='rgb(254, 247, 234)', 
    mask=mask,
    contour_width=0,
    min_font_size=5
).generate(pos_text_cln)

ax2.imshow(wordcloud2, interpolation='bilinear')
ax2.axis('off')
ax2.set_title('Palabras principales - Múltiples Donantes', fontsize=14, pad=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# > - Basándonos en las gráficas y comparaciones anteriores, podemos notar los siguientes puntos   <br><br>
#
# > - Un mayor porcentaje de proyectos en los que donó un solo donante tuvo las siguientes características:
# > - Pertenecientes a los grados **PreK-2**, publicados desde escuelas en **Áreas Urbanas**, con costos de proyecto menores, los maestros utilizaron ensayos de proyectos con **pocas palabras**, es decir, menos de 250, se publicaron en los meses de **septiembre, octubre y diciembre**, y trataban principalmente sobre **Libros**.
# > - Un mayor porcentaje de proyectos en los que donaron múltiples donantes tuvo las siguientes características:
# > - Pertenecientes a grados superiores, es decir, **Nivel de grado 3 - 12**, publicados desde escuelas en **áreas suburbanas y rurales**, tenían un costo de proyecto **mayor a 500 USD**, se utilizó un mayor número de palabras en los ensayos del proyecto, y estaban relacionados con **Tecnologías y Suministros**.
