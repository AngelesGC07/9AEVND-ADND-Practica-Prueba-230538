# %% [markdown]
# <center>
# <h1>Análitica de Datos para Negocios Digitales</h1>
# </center>

# %% [markdown]
# <center>
# <h3>Practica 05: Un viaje visual y revelador - DonorsChoose</h3>
# </center>

# %% [markdown]
# **Programa de estudios:** Ing. Entornos Virtuales y Negocios Digitales
# **Elaborado por:** María De Los Angeles García Cortez
# **Docente:** M.T.I Marco A. Ramírez Hernández
# **Grado/Grupo:** 9º "A"
# **Matrícula:** 230538
# **Periodo:** Mayo - Agosto 2026
